# %% [markdown]
# # Get Model Verification Data
# (from CARIACO hydrography master)
#
# this R notebook extracts Model Verification Data from the Hydrography Master (June 2018) file which is a collection monthly sampled data at CARIACO Ocean Time Series Station.

# %%
require(dplyr, warn.conflicts = FALSE);
#require(ggplot2);
require(cowplot, warn.conflicts = FALSE); # for nicer plots, includes ggplot2
# Out:
# Loading required package: dplyr
# Loading required package: cowplot
# Loading required package: ggplot2

# %%
# read processed hydrography master
phm <- read.csv("DATA_processed/Master_Hydrography_June2018_cleaned.csv")

# %%
names(phm) # check for available data
# Out:
#  [1] "X"                     "Cruise"                "Leg"
#  [4] "Day"                   "Month"                 "Year"
#  [7] "Date"                  "Depth_target"          "Depth_real"
# [10] "O2_.ml.L."             "O2_..mol.kg."          "NO3_UDO"
# [13] "PO4_UDO"               "Si.OH.4_UDO"           "NH4_USF"
# [16] "NO2_USF"               "NO3.NO2_USF"           "PO4_USF"
# [19] "Si.OH.4_USF"           "pH"                    "Alkalinity_.mol.kg."
# [22] "Alkalinity_..mol.kg."  "TCO2"                  "fCO2"
# [25] "pH_corrected"          "TCO2_corrected"        "fCO2_corrected"
# [28] "Salinity_bottles"      "Salinity_CTD"          "Temperature"
# [31] "Sigma.t"               "TPP"                   "PIP"
# [34] "POC_..g.kg."           "PN_..g.kg."            "POC_..g.L."
# [37] "PN_..g.L."             "C.N_particulate"       "DON"
# [40] "DOP"                   "DOC"                   "TOC"
# [43] "PrimaryProductivity"   "Chlorophyll"           "Phaeopigments"
# [46] "Total.Prokaryotes."    "Bact_Biomass_.mgC.m3." "Bact_Biomass_..MC."
# [49] "DateString"            "yday"

# %%
#convert date from character to ct for later plotting
phm$Date <- as.POSIXct(phm$Date, format="%Y-%m-%d")

# %%
# get only surface data (above 15 m depth)
# ChlA
phm_surface <- subset(phm, Depth_real <= 15)

# %%
#plotting Temperature data as a test
temp_y <- ggplot(phm_surface, aes(yday/30, Temperature, col=Depth_real)) +
  geom_point() + 
  xlab("Month") + ylab("Temperature [°C]") + scale_color_continuous(limits=c(0,20))
temp_y
# Out:
# Warning message:
# “Removed 8 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# now that the data is prepped
# # extract Data into csv
#
# - ChlA
# - Nitrate
# - Silicate
#
# Still to add:
# - Zooplankton (in another datafile!)

# %%
# ChlA # units: mg/m3
ChlA <- data.frame(phm_surface$yday,phm_surface$Chlorophyll)
names(ChlA) <- c("yday","ChlA")
ChlA <- ChlA[complete.cases(ChlA), ]
write.csv(ChlA, file = "../../DataFiles_Processed/ChlA_bottle_yearly_surface.csv", row.names=FALSE)

# %%
# Nitrate # µM (=mmol/m^3)
NO3NO2 <- data.frame(phm_surface$yday,phm_surface$NO3.NO2_USF)
names(NO3NO2) <- c("yday","NO3NO2")
NO3NO2 <- NO3NO2[complete.cases(NO3NO2), ]
write.csv(NO3NO2, file = "../../DataFiles_Processed/NO3NO2_bottle_yearly_surface.csv", row.names=FALSE)

# %%
# Silicate # µM (=mmol/m^3)
# two seperate columns as two seperate data files (due to change in lab)
SiOH_UDO <- data.frame(phm_surface$yday, phm_surface$Si.OH.4_UDO)
SiOH_USF <- data.frame(phm_surface$yday, phm_surface$Si.OH.4_USF)
names(SiOH_UDO) <- c("yday","SiOH")
names(SiOH_USF) <- c("yday","SiOH")
SiOH_UDO <- SiOH_UDO[complete.cases(SiOH_UDO), ]
SiOH_USF <- SiOH_USF[complete.cases(SiOH_USF), ]

write.csv(SiOH_UDO, file = "../../DataFiles_Processed/SiOH_UDO_bottle_yearly_surface.csv", row.names=FALSE)
write.csv(SiOH_USF, file = "../../DataFiles_Processed/SiOH_USF_bottle_yearly_surface.csv", row.names=FALSE)

# %% [markdown]
# # Get Zooplankton Data
# from the cleaned Zooplankton Master file

# %%
# Zooplankton
# Note: Tows were performed to 200 meters depth

# read file
zm <- read.csv("../../DataFiles_Processed/Master_Zooplankton_Nov2017_Cleaned.csv")

# %%
names(zm) # check for available data
zm
# Out:
#  [1] "X"                 "CRUISE"            "Date"
#  [4] "YEAR"              "MONTH"             "Analyst"
#  [7] "Mesh.Size"         "TOTAL.DENSITY"     "BIOMASS"
# [10] "ASH"               "COPEPODOS"         "CALANOIDS"
# [13] "CYCLOPOIDA"        "HAPARCTICOIDA"     "POECILOSTOMATOIDA"
# [16] "NA."               "L.FISH"            "H.FISH"
# [19] "CHAETOGNATHA"      "CLADOCEROS"        "OSTRACODA"
# [22] "FORAMINIFERA"      "AMPHIPODS"         "ISOPODS"
# [25] "EUPHAUSIIDS"       "MISYDACEA"         "SERGESTID"
# [28] "L.CRUSTACEA"       "N.COPEPOD"         "COPEPODITE"
# [31] "N.CIRRIPEDIA"      "L.CYPRIS"          "L.DECAPODA"
# [34] "L.STOMATOPODA"     "L.EUPHAUSIID"      "L.SERGESTID"
# [37] "NA.1"              "POLICHAETES"       "L.CYPHONAUTES"
# [40] "MEDUSA"            "SIPHONOPHORES"     "CTENOPHORES"
# [43] "L.ECHINODERMS"     "PTEROPODS"         "HETEROPODS"
# [46] "GASTROPODS"        "L.CEPHALOPODA"     "L.BIVALVE"
# [49] "L.GASTROPOD"       "PROTOZOAN"         "RADIOLARIAN"
# [52] "FORAMINIFERA.1"    "NA.2"              "NA.3"
# [55] "APPENDICULARIANS"  "SALPS"             "DOLIOLIDS"
# [58] "BIVALVES"          "H.CRUSTACEA"       "L.ANFIOXUS"
# [61] "LUCIFER"           "JUV..GASTROPOD"    "yday"
#     X    CRUISE Date       YEAR MONTH Analyst              Mesh.Size
# 1     1  71     2001-10-09 2001 10    Javier Gutierrez     500
# 2    20  72     2001-11-06 2001 11    Javier Gutierrez     500
# 3    39  73     2001-12-11 2001 12    Javier Gutierrez     500
# 4    58  74     2002-01-10 2002  1    Javier Gutierrez     500
# 5    59  74     2002-01-10 2002  1    Javier Gutierrez     200
# 6    96  75     2002-02-14 2002  2    Javier Gutierrez     200
# 7    97  75     2002-02-14 2002  2    Javier Gutierrez     500
# 8   134  76     2002-03-12 2002  3    Javier Gutierrez     200
# 9   135  76     2002-03-12 2002  3    Javier Gutierrez     500
# 10  172  77     2002-04-02 2002  4    Javier Gutierrez     200
# 11  173  77     2002-04-02 2002  4    Javier Gutierrez     500
# 12  210  78     2002-05-07 2002  5    Javier Gutierrez     500
# 13  211  78     2002-05-07 2002  5    Javier Gutierrez     200
# 14  248  79     2002-06-12 2002  6    Javier Gutierrez     500
# 15  249  79     2002-06-12 2002  6    Javier Gutierrez     200
# 16  286  80     2002-07-09 2002  7    Javier Gutierrez     200
# 17  287  80     2002-07-09 2002  7    Javier Gutierrez     500
# 18  324  81     2002-08-06 2002  8    Javier Gutierrez     200
# 19  325  81     2002-08-06 2002  8    Javier Gutierrez     500
# 20  362  82     2002-10-03 2002 10    Javier Gutierrez     500
# 21  363  82     2002-10-03 2002 10    Javier Gutierrez     200
# 22  400  83     2002-11-07 2002 11    Javier Gutierrez     500
# 23  401  83     2002-11-07 2002 11    Javier Gutierrez     200
# 24  438  84     2002-12-05 2002 12    Javier Gutierrez     200
# 25  439  84     2002-12-05 2002 12    Javier Gutierrez     500
# 26  476  85     2003-01-14 2003  1    Javier Gutierrez     200
# 27  477  85     2003-01-14 2003  1    Javier Gutierrez     500
# 28  514  86     2003-02-11 2003  2    Javier Gutierrez     200
# 29  515  86     2003-02-11 2003  2    Javier Gutierrez     500
# 30  552  87     2003-03-11 2003  3    Javier Gutierrez     500
# ⋮   ⋮    ⋮      ⋮          ⋮    ⋮     ⋮                    ⋮
# 274 5172 217    2014-12-04 2014 12    Jaimie Rojas Marquez 200
# 275 5173 217    2014-12-04 2014 12    Jaimie Rojas Marquez 500
# 276 5210 219    2015-03-10 2015  3    Jaimie Rojas Marquez 200
# 277 5211 219    2015-03-10 2015  3    Jaimie Rojas Marquez 500
# 278 5248 220    2015-04-24 2015  4    Jaimie Rojas Marquez 500
# 279 5249 220    2015-04-24 2015  4    Jaimie Rojas Marquez 200
# 280 5286 221    2015-07-29 2015  7    Jaimie Rojas Marquez 500
# 281 5287 221    2015-07-29 2015  7    Jaimie Rojas Marquez 200
# 282 5324 222    2015-08-18 2015  8    Jaimie Rojas Marquez 200
# 283 5325 222    2015-08-18 2015  8    Jaimie Rojas Marquez 500
# 284 5362 223    2015-09-10 2015  9    Jaimie Rojas Marquez 200
# 285 5363 223    2015-09-10 2015  9    Jaimie Rojas Marquez 500
# 286 5400 224    2015-11-16 2015 11    Jaimie Rojas Marquez 500
# 287 5401 224    2015-11-16 2015 11    Jaimie Rojas Marquez 200
# 288 5438 225    2015-12-09 2015 12    Jaimie Rojas Marquez 500
# 289 5439 225    2015-12-09 2015 12    Jaimie Rojas Marquez 200
# 290 5476 226    2016-01-12 2016  1    Jaimie Rojas Marquez 200
# 291 5477 226    2016-01-12 2016  1    Jaimie Rojas Marquez 500
# 292 5514 227    2016-02-04 2016  2    Jaimie Rojas Marquez 200
# 293 5515 227    2016-02-04 2016  2    Jaimie Rojas Marquez 500
# 294 5552 228    2016-05-11 2016  5    Jaimie Rojas Marquez 200
# 295 5553 228    2016-05-11 2016  5    Jaimie Rojas Marquez 500
# 296 5590 229    2016-06-07 2016  6    Jaimie Rojas Marquez 500
# 297 5591 229    2016-06-07 2016  6    Jaimie Rojas Marquez 200
# 298 5628 230    2016-09-20 2016  9    Jaimie Rojas Marquez 200
# 299 5629 230    2016-09-20 2016  9    Jaimie Rojas Marquez 500
# 300 5664 231    2016-12-21 2016 12    Jaimie Rojas Marquez 200
# 301 5665 231    2016-12-21 2016 12    Jaimie Rojas Marquez 500
# 302 5702 232    2017-01-12 2017  1    Jaimie Rojas Marquez 200
# 303 5703 232    2017-01-12 2017  1    Jaimie Rojas Marquez 500
#     TOTAL.DENSITY BIOMASS ASH  ⋯ NA.3 APPENDICULARIANS SALPS DOLIOLIDS BIVALVES
# 1    213          15.90   3.3  ⋯ NA    9.36             1.83 NA          NA
# 2     13           2.30   0.1  ⋯ NA    0.52             0.52 NA          NA
# 3      9           0.70   0.2  ⋯ NA    0.22             0.03 NA        0.03
# 4    105           4.90   0.18 ⋯ NA    0.10            18.00 NA        0.00
# 5    499          10.20   0.5  ⋯ NA    3.20            37.30 NA        1.60
# 6    612          12.90   2.6  ⋯ NA    5.00             1.70 NA          NA
# 7     NA             NA        ⋯ NA      NA               NA NA          NA
# 8    379          10.60   1.8  ⋯ NA    5.70             5.70 NA          NA
# 9     29           5.47   0.77 ⋯ NA      NA             2.20 NA        0.10
# 10   572           8.70   1.8  ⋯ NA   13.30             3.10 NA        1.00
# 11     7           8.31   2.15 ⋯ NA    0.20             0.30 NA          NA
# 12    96           1.31   0.09 ⋯ NA    0.20             0.20 NA          NA
# 13   247           4.50   0.4  ⋯ NA    7.00             1.30 NA          NA
# 14    16           4.54   0.35 ⋯ NA    4.00             1.30 NA          NA
# 15   313          10.60   1.1  ⋯ NA    3.40             0.40 NA          NA
# 16    97           1.40   0.5  ⋯ NA    0.10               NA NA        0.10
# 17    60           0.88   0.13 ⋯ NA      NA             0.00 NA          NA
# 18  1075           1.80   0.4  ⋯ NA   35.30             1.60 NA          NA
# 19   143           1.28   0.31 ⋯ NA    1.20             0.90 NA          NA
# 20   184           1.50   0.36 ⋯ NA    0.60             2.40 NA        0.90
# 21  2269          12.40   5.7  ⋯ NA   28.40             4.70 NA          NA
# 22    47           3.33   1.06 ⋯ NA    0.20             0.90 NA          NA
# 23   779           4.80   1.1  ⋯ NA      NA               NA NA          NA
# 24   615           5.50   1.6  ⋯ NA    1.30            22.10 NA          NA
# 25    41           1.90   0.51 ⋯ NA    0.10             1.80 NA          NA
# 26   740          12.00   2.6  ⋯ NA      NA             1.30 NA          NA
# 27   132           4.74   1.11 ⋯ NA      NA             1.00 NA          NA
# 28   168          11.80   4.4  ⋯ NA      NA               NA NA          NA
# 29    57           8.74   3.2  ⋯ NA      NA               NA NA        2.30
# 30    79          11.38   4    ⋯ NA    0.20             0.20 NA          NA
# ⋮   ⋮             ⋮       ⋮    ⋱ ⋮    ⋮                ⋮     ⋮         ⋮
# 274  511          11.70   4.0  ⋯ NA   15.9             NA     NA       NA
# 275   67           4.49   1.14 ⋯ NA     NA             NA     NA       NA
# 276  634          16.40   2.2  ⋯ NA     NA             NA     NA       NA
# 277   34           8.20   2.60 ⋯ NA     NA             NA     NA       NA
# 278   73           6.70   2.56 ⋯ NA     NA             NA     NA       NA
# 279   59           6.10   2.0  ⋯ NA     NA             NA     NA       NA
# 280  195           8.11   2.27 ⋯ NA     NA             NA     NA       NA
# 281  487           9.80   2.0  ⋯ NA    0.8             NA     NA       NA
# 282  713          16.30   5.2  ⋯ NA    9.6             NA     NA       NA
# 283  251          12.71   5.57 ⋯ NA    1.5             NA     NA       NA
# 284  779          12.10   4.3  ⋯ NA   17.8             NA     NA       NA
# 285  169           6.47   9.32 ⋯ NA     NA             NA    0.4       NA
# 286   99           4.62   1.34 ⋯ NA     NA             NA     NA       NA
# 287 1560           6.40   1.3  ⋯ NA    4.4             NA     NA       NA
# 288  116           3.19   0.65 ⋯ NA     NA             NA     NA       NA
# 289  263           5.70   1.6  ⋯ NA     NA             NA     NA       NA
# 290  480           7.20   2.2  ⋯ NA    4.4             NA     NA       NA
# 291  120           3.86   1.42 ⋯ NA    1.4             NA     NA       NA
# 292  373          13.60   7.7  ⋯ NA    4.2             NA     NA       NA
# 293   89           5.16   2.35 ⋯ NA     NA             NA    1.4       NA
# 294  305           4.70   1.1  ⋯ NA     NA             NA     NA       NA
# 295  115           3.75   1.16 ⋯ NA     NA             NA     NA       NA
# 296   41           1.04   0.47 ⋯ NA     NA             NA     NA       NA
# 297  425           3.00   1.0  ⋯ NA     NA             NA     NA       NA
# 298  412           9.20   3.4  ⋯ NA     NA             NA     NA       NA
# 299  132           7.91   3.03 ⋯ NA     NA             NA     NA       NA
# 300  216           4.10   0.9  ⋯ NA     NA             NA     NA       NA
# 301   26           1.27   0.32 ⋯ NA     NA             NA     NA       NA
# 302  759           3.10   0.7  ⋯ NA     NA             NA     NA       NA
# 303  132           0.97   0.25 ⋯ NA    1.6             NA     NA       NA
#     H.CRUSTACEA L.ANFIOXUS LUCIFER JUV..GASTROPOD yday
# 1     NA                    NA                    281
# 2     NA                    NA                    309
# 3   0.26                    NA                    344
# 4   0.30                   0.4                      9
# 5   1.60        n.d.        NA     n.d.             9
# 6   3.30        n.d.        NA     n.d.            44
# 7     NA                    NA                     44
# 8     NA        n.d.       1.1     n.d.            70
# 9     NA                   0.4                     70
# 10    NA        n.d.        NA     n.d.            91
# 11    NA                   0.1                     91
# 12    NA                    NA                    126
# 13    NA        n.d.        NA     n.d.           126
# 14    NA                   0.5                    162
# 15    NA        n.d.        NA     n.d.           162
# 16    NA        n.d.        NA     n.d.           189
# 17    NA                   0.2                    189
# 18    NA        n.d.        NA     n.d.           217
# 19    NA                    NA                    217
# 20    NA                   1.2                    275
# 21    NA        n.d.        NA     n.d.           275
# 22  1.40                   0.4                    310
# 23  4.20        n.d.        NA     n.d.           310
# 24    NA        n.d.       2.6     n.d.           338
# 25    NA                    NA                    338
# 26  8.00        n.d.        NA     n.d.            13
# 27    NA                   0.2                     13
# 28    NA        n.d.       0.7     n.d.            41
# 29    NA                    NA                     41
# 30    NA                    NA                     69
# ⋮   ⋮           ⋮          ⋮       ⋮              ⋮
# 274 NA                     NA                     337
# 275 NA                     NA                     337
# 276 NA                     NA                      68
# 277 NA                     NA                      68
# 278 NA                     NA                     113
# 279 NA                     NA                     113
# 280 NA                     NA                     209
# 281 NA                     NA                     209
# 282 NA                     NA                     229
# 283 NA                     NA                     229
# 284 NA                     NA                     252
# 285 NA                     NA                     252
# 286 NA                     NA                     319
# 287 NA                     NA                     319
# 288 NA                     NA                     342
# 289 NA                     NA                     342
# 290 NA                     NA                      11
# 291 NA                     NA                      11
# 292 NA                     NA                      34
# 293 NA                     NA                      34
# 294 NA                     NA                     131
# 295 NA                     NA                     131
# 296 NA                     NA                     158
# 297 NA                     NA                     158
# 298 NA                     NA                     263
# 299 NA                     NA                     263
# 300 NA                     NA                     355
# 301 NA                     NA                     355
# 302 NA                     NA                      11
# 303 NA                     NA                      11

# %%
#plotting Biomass data as a test
zmbm_y <- ggplot(zm, aes(yday/30, BIOMASS, col=as.factor(Mesh.Size))) +
  geom_point() + 
  xlab("Month") + ylab(bquote('Biomass [mg/'~m^3~'] dry weight')) 

zmbm_y
# Out:
# Warning message:
# “Removed 4 rows containing missing values (geom_point).”
# plot without title

# %%
# add both mesh values together for each cruise to get TOTAL ZOO Biomass
zmBM_agg <- zm %>% 
  group_by(CRUISE) %>% 
  summarise(BIOMASS = sum(BIOMASS),yday = max(yday))

# %%
# Zooplankton Biomass # [mg/m^3 dry weight]
ZooBM <- data.frame(zmBM_agg$yday, zmBM_agg$BIOMASS)
names(ZooBM) <- c("yday","ZooBM")
ZooBM <- ZooBM[complete.cases(ZooBM), ]
write.csv(ZooBM, file = "../../DataFiles_Processed/ZooBM_All.csv", row.names=FALSE)
