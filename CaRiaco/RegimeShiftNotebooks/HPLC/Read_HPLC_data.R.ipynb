# %% [markdown]
# # Now Let's read this HPLC data, and get some functional type info outta there

# %%
require(dplyr, warn.conflicts = FALSE);
#require(ggplot2);
require(cowplot, warn.conflicts = FALSE); # for nicer plots, includes ggplot2
require(chron, warn.conflicts = FALSE);
require(ncdf4, warn.conflicts = FALSE);
# Out:
# Loading required package: dplyr
# Loading required package: cowplot
# Loading required package: ggplot2
# Loading required package: chron
# Loading required package: ncdf4

# %%
# open a NetCDF file
HPLC_Mote <- nc_open("HPLC_Mote.netcdf")

# print(nctdin)

HPLC_Mote_df <- data.frame("Num" = 1:HPLC_Mote$dim$unlimited$len)
for(i in 1:HPLC_Mote$nvars) {
    HPLC_Mote_df[paste(attributes(HPLC_Mote$var)$names[i])] <- ncvar_get(HPLC_Mote, attributes(HPLC_Mote$var)$names[i])
}
head(HPLC_Mote_df)
# Out:
#   Num Year Cruise_ID Leg Cast lon    lat  Mon Day Date     ⋯ neox  antherax
# 1 1   1999 93HG_039  1   4    -64.67 10.5 2   10  19990210 ⋯ -9999
# 2 2   1999 93HG_039  1   4    -64.67 10.5 2   10  19990210 ⋯ -9999
# 3 3   1999 93HG_039  1   4    -64.67 10.5 2   10  19990210 ⋯ -9999
# 4 4   1999 93HG_039  1   4    -64.67 10.5 2   10  19990210 ⋯ -9999
# 5 5   1999 93HG_039  1   4    -64.67 10.5 2   10  19990210 ⋯ -9999
# 6 6   1999 93HG_039  1   4    -64.67 10.5 2   10  19990210 ⋯ -9999
#   violax p_phytin_a prasinox gyrox       chl_a_allo  chl_a_prime chl_a_fluor
# 1 -9999             -9999    9.96921e+36 9.96921e+36 9.96921e+36 9.96921e+36
# 2 -9999             -9999    9.96921e+36 9.96921e+36 9.96921e+36 9.96921e+36
# 3 -9999             -9999    9.96921e+36 9.96921e+36 9.96921e+36 9.96921e+36
# 4 -9999             -9999    9.96921e+36 9.96921e+36 9.96921e+36 9.96921e+36
# 5 -9999             -9999    9.96921e+36 9.96921e+36 9.96921e+36 9.96921e+36
# 6 -9999             -9999    9.96921e+36 9.96921e+36 9.96921e+36 9.96921e+36
#   chl_a_pheo_fluor
# 1 9.96921e+36
# 2 9.96921e+36
# 3 9.96921e+36
# 4 9.96921e+36
# 5 9.96921e+36
# 6 9.96921e+36

# %%
# Write CSV in R
write.csv(HPLC_Mote_df, file = "HPLC_Mote_df.csv")

# %%
# open a NetCDF file
HPLC_BBSR <- nc_open("HPLC_BBSR.netcdf")

# print(nctdin)

HPLC_BBSR_df <- data.frame("Num" = 1:HPLC_BBSR$dim$unlimited$len)
for(i in 1:HPLC_BBSR$nvars) {
    HPLC_BBSR_df[paste(attributes(HPLC_BBSR$var)$names[i])] <- ncvar_get(HPLC_BBSR, attributes(HPLC_BBSR$var)$names[i])
}
tail(HPLC_BBSR_df)
# Out:
#     Num Year Cruise_ID Leg Cast lon    lat  Mon Day Date     ⋯ fucox diadinox
# 242 242 1998 93HG_030  1   4    -64.67 10.5 4   21  19980421 ⋯ 0.011 0.046
# 243 243 1998 93HG_030  1   4    -64.67 10.5 4   21  19980421 ⋯ 0.107 0.021
# 244 244 1998 93HG_030  1   4    -64.67 10.5 4   21  19980421 ⋯ 0.026 0.015
# 245 245 1998 93HG_030  1   4    -64.67 10.5 4   21  19980421 ⋯ 0.029 0.017
# 246 246 1998 93HG_030  1   4    -64.67 10.5 4   21  19980421 ⋯ 0.013 0.005
# 247 247 1998 93HG_030  1   4    -64.67 10.5 4   21  19980421 ⋯ 0.007 0.001
#     allox diatox lutein peridinin prasinox zeax  chl_a_fluor chl_a_pheo_fluor
# 242 0     0      0      0.016     0.001    0.002 0.272       0.063
# 243 0     0      0      0.014     0.020    0.032 0.701       0.436
# 244 0     0      0      0.002     0.016    0.032 0.409       0.402
# 245 0.004 0      0      0.006     0.008    0.024 0.300       0.307
# 246 0.003 0      0      0.002     0.001    0.004 0.094       0.101
# 247 0.001 0      0      0.001     0.001    0.001 0.049       0.088

# %%
# Write CSV in R
write.csv(HPLC_BBSR_df, file = "HPLC_BBSR_df.csv")

# %%
# open a NetCDF file
HPLC_HPL <- nc_open("HPLC_HPL.netcdf")

# print(nctdin)

HPLC_HPL_df <- data.frame("Num" = 1:HPLC_HPL$dim$unlimited$len)
for(i in 1:HPLC_HPL$nvars) {
    HPLC_HPL_df[paste(attributes(HPLC_HPL$var)$names[i])] <- ncvar_get(HPLC_HPL, attributes(HPLC_HPL$var)$names[i])
}
head(HPLC_HPL_df)
# Out:
#   Num Year lon_n  lat_n Cruise_ID leg cast lon      lat     Mon ⋯
# 1 1   2006 -64.67 10.5  93HG_124  1   4    -64.6605 10.5059 07  ⋯
# 2 2   2006 -64.67 10.5  93HG_124  1   4    -64.6605 10.5059 07  ⋯
# 3 3   2006 -64.67 10.5  93HG_124  1   4    -64.6605 10.5059 07  ⋯
# 4 4   2006 -64.67 10.5  93HG_124  1   4    -64.6605 10.5059 07  ⋯
# 5 5   2006 -64.67 10.5  93HG_124  1   4    -64.6605 10.5059 07  ⋯
# 6 6   2006 -64.67 10.5  93HG_124  1   4    -64.6605 10.5059 07  ⋯
#   pigpsc_to_cartot pigppc_to_cartot chltot_to_cartot pigppc_to_pigtot
# 1
# 2
# 3
# 4
# 5
# 6
#   pigpsp_to_pigtot pigpsc_to_pigtot chla_tot_to_pigtot micro_PF nano_PF pico_PF
# 1
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# What I need for Chemtax:
# - chl c1-c2
# - chl c3
# - peridinin
# - but-fuco
# - fucoxanthin
# - hex-fuco
# - prasinoxanthin
# - lutein
# - alloxanthin
# - zeaxanthin
# - chl b
# - chl a

# %%
ChemTax_BBSR <- data.frame('Date'=HPLC_BBSR_df$Date,'Cruise_ID'=HPLC_BBSR_df$Cruise_ID,'depth'=HPLC_BBSR_df$depth,'chl c1-c2'=HPLC_BBSR_df$chl_c1_c2, 'chl c3'=HPLC_BBSR_df$chl_c3, 
                           'peridinin'=HPLC_BBSR_df$peridinin, 'but-fuco'=HPLC_BBSR_df$fucox_but, 'fucoxanthin'=HPLC_BBSR_df$fucox,
                           'hex-fuco'=HPLC_BBSR_df$fucox_hex, 'prasinoxanthin'=HPLC_BBSR_df$prasinox, 'lutein'=HPLC_BBSR_df$lutein, 
                           'alloxanthin'=HPLC_BBSR_df$allox, 'zeaxanthin'=HPLC_BBSR_df$zeax, 'chl b'=HPLC_BBSR_df$chl_b_tot, 'chl a'=HPLC_BBSR_df$chl_a_tot)

head(ChemTax_BBSR)
# Out:
#   Date     Cruise_ID depth chl.c1.c2 chl.c3 peridinin but.fuco fucoxanthin
# 1 19951214 93HG_002  1     0.004     0      0.005     0.002    0.008
# 2 19951214 93HG_002  7     0.002     0      0.006     0.002    0.009
# 3 19951214 93HG_002  15    0.004     0      0.01      0.003    0.008
# 4 19951214 93HG_002  25    0.021     0.014  0.008     0.021    0.065
# 5 19951214 93HG_002  35    0.011     0.006  0.009     0.01     0.034
# 6 19951214 93HG_002  55    0.002     0.001  0         0.003    0.009
#   hex.fuco prasinoxanthin lutein alloxanthin zeaxanthin chl.b chl.a
# 1 0.008    0.003          0      0           0.004      0.018 0.107
# 2 0.01     0.004          0      0.001       0.008      0.025 0.139
# 3 0.011    0.003          0      0.001       0.008      0.032 0.163
# 4 0.086    0.015          0      0.006       0.024      0.141 0.408
# 5 0.042    0.002          0      0.002       0.012      0.107 0.241
# 6 0.011    0.000          0      0           0.005      0.053 0.088

# %%
ChemTax_HPL <- data.frame('Date'=HPLC_HPL_df$Date, 'Cruise_ID'=HPLC_HPL_df$Cruise_ID, 'depth'=HPLC_HPL_df$depth,'chl c1-c2'=HPLC_HPL_df$chl_c1_c2, 'chl c3'=HPLC_HPL_df$chl_c3, 
                          'peridinin'=HPLC_HPL_df$peridinin, 'but-fuco'=HPLC_HPL_df$fucox_but, 'fucoxanthin'=HPLC_HPL_df$fucox,
                          'hex-fuco'=HPLC_HPL_df$fucox_hex, 'prasinoxanthin'=HPLC_HPL_df$prasinox, 'lutein'=HPLC_HPL_df$lutein, 
                          'alloxanthin'=HPLC_HPL_df$allox, 'zeaxanthin'=HPLC_HPL_df$zeax,'chl b'=HPLC_HPL_df$chl_b_tot, 'chl a'=HPLC_HPL_df$chl_a_tot)

head(ChemTax_HPL)
# Out:
#   Date     Cruise_ID depth chl.c1.c2 chl.c3 peridinin but.fuco fucoxanthin
# 1 20060704 93HG_124  1               0.0184 0.0082    0.0054   0.0555
# 2 20060704 93HG_124  7               0.0179 0.0074    0.0048   0.0574
# 3 20060704 93HG_124  15              0.0154 0.0087    0.0040   0.0482
# 4 20060704 93HG_124  25              0.0119 0.0084    0.0060   0.0103
# 5 20060704 93HG_124  35              0.0109 0.0080    0.0047   0.0030
# 6 20060704 93HG_124  55              0.0123 bd        0.0078   0.0129
#   hex.fuco prasinoxanthin lutein alloxanthin zeaxanthin chl.b chl.a
# 1 0.0205   bd             bd     bd          0.0392           0.2500
# 2 0.0190   bd             bd     bd          0.0392           0.2667
# 3 0.0170   bd             bd     bd          0.0345           0.2438
# 4 0.0216   bd             bd     0.0012      0.0474           0.1967
# 5 0.0226   0.0053         bd     0.0008      0.0237           0.1972
# 6 0.0192   0.0013         bd     bd          0.0015           0.0724

# %%
ChemTax_Mote <- data.frame('Date'=HPLC_Mote_df$Date,'Cruise_ID'=HPLC_Mote_df$Cruise_ID,'depth'=HPLC_Mote_df$depth,'chl c1-c2'=HPLC_Mote_df$chl_c1_c2, 'chl c3'=HPLC_Mote_df$chl_c3, 
                          'peridinin'=HPLC_Mote_df$peridinin, 'but-fuco'=HPLC_Mote_df$fucox_but, 'fucoxanthin'=HPLC_Mote_df$fucox,
                          'hex-fuco'=HPLC_Mote_df$fucox_hex, 'prasinoxanthin'=HPLC_Mote_df$prasinox, 'lutein'=HPLC_Mote_df$lutein, 
                          'alloxanthin'=HPLC_Mote_df$allox, 'zeaxanthin'=HPLC_Mote_df$zeax,'chl b'=HPLC_Mote_df$chl_b_tot, 'chl a'=HPLC_Mote_df$chl_a_tot)

head(ChemTax_Mote)
# Out:
#   Date     Cruise_ID depth chl.c1.c2 chl.c3 peridinin but.fuco fucoxanthin
# 1 19990210 93HG_039  2     0.4307    0.1705 -9999     -9999    0.7472
# 2 19990210 93HG_039  7     0.8283    0.3753 -9999     -9999    1.2577
# 3 19990210 93HG_039  16    0.7439    0.3305 -9999     -9999    0.5679
# 4 19990210 93HG_039  25    0.8701    0.3181 -9999     -9999    0.7764
# 5 19990210 93HG_039  35    1.347     0.5773 -9999     -9999    2.1701
# 6 19990210 93HG_039  55    0.0505    -9999  -9999     -9999    0.1162
#   hex.fuco prasinoxanthin lutein alloxanthin zeaxanthin chl.b chl.a
# 1 0.0979   -9999          -9999  -9999       -9999      -9999 2.4333
# 2 0.1111   -9999          -9999  -9999       -9999      -9999
# 3 -9999    -9999          -9999  -9999       -9999      -9999
# 4 0.0372   -9999          -9999  -9999       -9999      -9999
# 5 0.1741   -9999          -9999  -9999       -9999      -9999
# 6 0.0056   -9999          -9999  -9999       -9999      -9999

# %%
ChemTax_BBSR$date <- as.POSIXct(as.character(ChemTax_BBSR$Date), format="%Y%m%d")
ChemTax_Mote$date <- as.POSIXct(as.character(ChemTax_Mote$Date), format="%Y%m%d")
ChemTax_HPL$date <- as.POSIXct(as.character(ChemTax_HPL$Date), format="%Y%m%d")

# %%
head(ChemTax_BBSR)
# Out:
#   Date     Cruise_ID depth chl.c1.c2 chl.c3 peridinin but.fuco fucoxanthin
# 1 19951214 93HG_002  1     0.004     0      0.005     0.002    0.008
# 2 19951214 93HG_002  7     0.002     0      0.006     0.002    0.009
# 3 19951214 93HG_002  15    0.004     0      0.01      0.003    0.008
# 4 19951214 93HG_002  25    0.021     0.014  0.008     0.021    0.065
# 5 19951214 93HG_002  35    0.011     0.006  0.009     0.01     0.034
# 6 19951214 93HG_002  55    0.002     0.001  0         0.003    0.009
#   hex.fuco prasinoxanthin lutein alloxanthin zeaxanthin chl.b chl.a date
# 1 0.008    0.003          0      0           0.004      0.018 0.107 1995-12-14
# 2 0.01     0.004          0      0.001       0.008      0.025 0.139 1995-12-14
# 3 0.011    0.003          0      0.001       0.008      0.032 0.163 1995-12-14
# 4 0.086    0.015          0      0.006       0.024      0.141 0.408 1995-12-14
# 5 0.042    0.002          0      0.002       0.012      0.107 0.241 1995-12-14
# 6 0.011    0.000          0      0           0.005      0.053 0.088 1995-12-14

# %%
ChemTax_Mote$chl.a[ChemTax_Mote$chl.a=="0"]
# Out:
# character(0)

# %%
ChemTax_Mote$chl.a[ChemTax_Mote$chl.a=="-9999"] <- "0"

# %%
options(repr.plot.width=10, repr.plot.height=4)
ggplot()+
geom_point(data=ChemTax_BBSR,aes(x=date, y=as.numeric(chl.a)))+
geom_point(data=ChemTax_Mote,aes(x=date, y=as.numeric(chl.a), col='blue'))+
scale_x_datetime(date_breaks = "1 year")+
ggtitle('BBSR + Mote')

ggplot()+
geom_point(data=ChemTax_HPL,aes(x=date, y=as.numeric(chl.a)))+
ggtitle('HPL')
# Out:
# Warning message:
# “Removed 80 rows containing missing values (geom_point).”
# plot without title
# plot without title

# %%
DateString <- date
Date <- as.POSIXlt(as.character(date), format="%Y%m%d")

days <- Date$yday

# %%
# Write CSV in R
write.csv(ChemTax_HPL, file = "ChemTax_HPL.csv")
# Write CSV in R
write.csv(ChemTax_Mote, file = "ChemTax_Mote.csv")
# Write CSV in R
write.csv(ChemTax_BBSR, file = "ChemTax_BBSR.csv")
