# %% [markdown]
# # Time Series Overview plots
#
# ### Introduction to Time Series in Presentation
# plot multiple variables together, showing overall dynamics, and showcase the wealth of data available

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
CARIACO = pd.read_csv("../DATA/January/Combined_CARIACO_data_v6.csv")
CARIACO['date'] = pd.to_datetime(CARIACO['time_month'])
CARIACO = CARIACO.set_index('date')

# %%
ERA5_META = pd.read_csv("../annotatedDATA/META/ERA5_META.csv")

# %%
# yearly mean resample
CARIACO_yrly_mean = CARIACO.groupby(CARIACO.index.year).mean()
CARIACO_yrly_counts = CARIACO.groupby(CARIACO.index.year).count()

CARIACO_yrly_mean[CARIACO_yrly_counts<5] = np.nan

# %%
CARIACO_yrly_mean.index = pd.to_datetime(CARIACO_yrly_mean.index, format="%Y")

# %% [markdown]
# ## first plot
# - Temperature
# - pH
# - NO3
# - PO4
# - SiO4
#
# ## second plot
# - Chlorophyll
# - NPP
# - Phaeopigment
# - Zooplankton (tot biomass)
#
# ## third plot (ERA5)
# - Wind (-u)
# - sst
# - precipitation
# - evaporation
# - irradiance
#
# ## fourth plot (Satellite)
# - MODIS
# - SeaWiFS
# - MERGED

# %%
import pandas as pd
#import pandas_datareader.data as web

import numpy as np
#import matplotlib as mpl
import matplotlib.pyplot as plt
#%matplotlib inline
import matplotlib.dates as mdates

#import seaborn 
#sns.set_style('white', {"xtick.major.size": 2, "ytick.major.size": 2})
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71","#f4cae4"]
#sns.set_palette(sns.color_palette(flatui,7))

# %%
#seaborn.boxplot(x=CARIACO.index.year, y=CARIACO.Tot_Chl_a, color='tab:green', showfliers=False

# %%
# Let's plot SPX and VIX cumulative returns with recession overlay
plot_cols = ['Temperature', 'pH_corrected', 'NO3_USF', 'PO4_USF', 'SiO4_USF']
y_label = ['°C', 'pH', 'µM', 'µM', 'µM']
no_of_rows = len(plot_cols)


def plottimeseries(plot_cols, y_label, no_of_rows, title="", same_ylim=False, ylim=""):
    #colr_dict = {plot_cols[0]:flatui[0], plot_cols[1]:flatui[1],
    #            plot_cols[2]:flatui[2], plot_cols[3]:flatui[3],
    #            plot_cols[4]:flatui[4]}
    
    colr_dict = {col:flatui[i] for col, i in zip(plot_cols, range(no_of_rows))}

    #label_dict = {plot_cols[0]:y_label[0], plot_cols[1]:y_label[1],
    #            plot_cols[2]:y_label[2], plot_cols[3]:y_label[3],
    #            plot_cols[4]:y_label[4]}
    
    label_dict = {col:label for col, label in zip(plot_cols, y_label)}
    # 2 axes for 2 subplots

    fig, axes = plt.subplots(no_of_rows,1, figsize=(15,12), sharex=True)

    axes[0].set_title(title)

    axes[0].tick_params(labelbottom=False,labeltop=True)

    for col, ax in zip(plot_cols, axes):
        print(col)
        seaborn.boxplot(x=CARIACO.index.year, y=CARIACO[col], color=colr_dict[col], showfliers=True, ax=ax)
        ax.set_ylabel(col + ' \n [' +label_dict[col] + ']', size=14)
        #ax.legend(loc='upper right', fontsize='large')

        ax.xaxis.set_minor_locator(mdates.YearLocator())

        #ax.grid(True,which='both', color='lightgrey')
        ax.tick_params(top=False, right=True, direction="in")
    
        if same_ylim:
            ax.set_ylim(ylim)
    
    plt.subplots_adjust(wspace=0, hspace=0)
    fig.align_ylabels()
    


#CARIACO[plot_cols].plot(kind='scatter', subplots=True, ax=axes)
#for ax in axes:
#    ax.axvspan(recs2k_bgn, recs2k_end, color=sns.xkcd_rgb['grey'], alpha=0.5)
#    ax.axvspan(recs2k8_bgn, recs2k8_end,  color=sns.xkcd_rgb['grey'], alpha=0.5)

# %% [markdown]
# # PLOT 1

# %%
plot_cols = ['Temperature', 'pH_corrected', 'NO3_USF', 'PO4_USF', 'SiO4_USF']
y_label = ['°C', 'pH', 'µM', 'µM', 'µM']
no_of_rows = len(plot_cols)

plottimeseries(plot_cols, y_label, no_of_rows, title='Integrated 100 m')
plt.savefig("NewTimeSeriesPlots/TS1_TemppHNuts_100m.png")
# Out:
# Temperature
# pH_corrected
# NO3_USF
# PO4_USF
# SiO4_USF

# %%
plot_cols = ['Temperature_35m', 'pH_corrected_35m', 'NO3_USF_35m', 'PO4_USF_35m', 'SiO4_USF_35m']
y_label = ['°C', 'pH', 'µM', 'µM', 'µM']
no_of_rows = len(plot_cols)

plottimeseries(plot_cols, y_label, no_of_rows, title='Integrated top 35 m')
plt.savefig("NewTimeSeriesPlots/TS1_TemppHNuts_35m.png")
# Out:
# Temperature_35m
# pH_corrected_35m
# NO3_USF_35m
# PO4_USF_35m
# SiO4_USF_35m

# %%
plot_cols = ['Temperature_35to100m', 'pH_corrected_35to100m', 'NO3_USF_35to100m', 'PO4_USF_35to100m', 'SiO4_USF_35to100m']
y_label = ['°C', 'pH', 'µM', 'µM', 'µM']
no_of_rows = len(plot_cols)

plottimeseries(plot_cols, y_label, no_of_rows, title='Integrated 35 - 100 m')
plt.savefig("NewTimeSeriesPlots/TS1_TemppHNuts_35to100m.png")
# Out:
# Temperature_35to100m
# pH_corrected_35to100m
# NO3_USF_35to100m
# PO4_USF_35to100m
# SiO4_USF_35to100m

# %% [markdown]
# # PLOT 2

# %%
plot_cols = ['Chlorophyll', 'PrimaryProductivity', 'Phaeopigments', 'total_biomass']
y_label = ['mg $\mathrm{m}^{-3}$', 'mg C $\mathrm{m}^{-3}$ $\mathrm{h}^{-1}$', 'mg $\mathrm{m}^{-3}$', 'Zoo mg $\mathrm{m}^{-3}$']
no_of_rows = len(plot_cols)

plottimeseries(plot_cols, y_label, no_of_rows, title='Integrated 100 m')
plt.savefig("NewTimeSeriesPlots/TS1_ChlorophyllNPPPhaeoZoo_100m.png")
# Out:
# Chlorophyll
# PrimaryProductivity
# Phaeopigments
# total_biomass

# %%
plot_cols = ['Chlorophyll_35m', 'PrimaryProductivity_35m', 'Phaeopigments_35m']
y_label = ['mg $\mathrm{m}^{-3}$', 'mg C $\mathrm{m}^{-3}$ $\mathrm{h}^{-1}$', 'mg $\mathrm{m}^{-3}$']
no_of_rows = len(plot_cols)

plottimeseries(plot_cols, y_label, no_of_rows, title='Integrated top 35 m')
plt.savefig("NewTimeSeriesPlots/TS1_ChlorophyllNPPPhaeoZoo_35m.png")
# Out:
# Chlorophyll_35m
# PrimaryProductivity_35m
# Phaeopigments_35m

# %%
plot_cols = ['Chlorophyll_35to100m', 'PrimaryProductivity_35to100m', 'Phaeopigments_35to100m']
y_label = ['mg $\mathrm{m}^{-3}$', 'mg C $\mathrm{m}^{-3}$ $\mathrm{h}^{-1}$', 'mg $\mathrm{m}^{-3}$']
no_of_rows = len(plot_cols)

plottimeseries(plot_cols, y_label, no_of_rows, title='Integrated 35 - 100 m')
plt.savefig("NewTimeSeriesPlots/TS1_ChlorophyllNPPPhaeoZoo_35m.png")
# Out:
# Chlorophyll_35to100m
# PrimaryProductivity_35to100m
# Phaeopigments_35to100m

# %% [markdown]
# # PLOT 3

# %%
plot_cols = ['wind','u10', 'cdir', 'mtpr']
y_label = ['m $\mathrm{s}^{-1}$', 'm $\mathrm{s}^{-1}$', 'PAR', 'Precipitation']
no_of_rows = len(plot_cols)

plottimeseries(plot_cols, y_label, no_of_rows, title='ERA5 data')
plt.savefig("NewTimeSeriesPlots/TS3_ERA5.png")
# Out:
# wind
# u10
# cdir
# mtpr

# %% [markdown]
# # PlOT 4

# %%
plot_cols = ['SeaWiFS_chla', 'MODIS_chla', 'Satellite_chla', 'Chlorophyll_35m']
y_label = ['mg $\mathrm{m}^{-3}$', 'mg $\mathrm{m}^{-3}$', 'mg $\mathrm{m}^{-3}$', 'mg $\mathrm{m}^{-3}$']
no_of_rows = len(plot_cols)

plottimeseries(plot_cols, y_label, no_of_rows, title='Sat Chla data', same_ylim=True, ylim=(0,7))
plt.savefig("NewTimeSeriesPlots/TS4_ChlorophyllSatellite.png")
# Out:
# SeaWiFS_chla
# MODIS_chla
# Satellite_chla
# Chlorophyll_35m

# %% [markdown]
# # Extra PLOTS

# %%
## func group test plot

# %%
plot_cols = ['Tchla', 'Diatom1', 'Hapto6', 'Cyano4', 'Chloro1', 'Crypto1', 'Prasino3']
y_label = ['mg $\mathrm{m}^{-2}$', 'mg $\mathrm{m}^{-2}$', 'mg $\mathrm{m}^{-2}$', 'mg $\mathrm{m}^{-2}$', 'mg $\mathrm{m}^{-2}$', 'mg $\mathrm{m}^{-2}$', 'mg $\mathrm{m}^{-2}$']
no_of_rows = len(plot_cols)

plottimeseries(plot_cols, y_label, no_of_rows, title='HPLC data - 100m integrated')
plt.savefig("NewTimeSeriesPlots/TS4_ChlorophyllSatellite.png")
# Out:
# Tchla
# Diatom1
# Hapto6
# Cyano4
# Chloro1
# Crypto1
# Prasino3

# %% [markdown]
# # PLOTS:
#
# - time series of summer values + winter values (time series with period 12)
# -

# %%
def plottimeseries2(plot_cols, y_label, no_of_rows, title="", same_ylim=False, ylim=""):
    
    colr_dict = {col:flatui[i] for col, i in zip(plot_cols, range(no_of_rows))}
    label_dict = {col:label for col, label in zip(plot_cols, y_label)}
    # 2 axes for 2 subplots

    fig, axes = plt.subplots(no_of_rows,1, figsize=(15,12), sharex=True)

    axes[0].set_title(title)
    axes[0].tick_params(labelbottom=False,labeltop=True)

    for col, ax in zip(plot_cols, axes):
        print(col)
        
        ax.grid(True,which='both', color='lightgrey')
        dat = CARIACO[col].groupby(CARIACO.index.year, dropna=False).std()
        #seaborn.boxplot(x=CARIACO.index.year, y=CARIACO[col], color=colr_dict[col], showfliers=True, ax=ax)
        ax.plot(dat.index, dat)
        ax.set_ylabel(col + ' \n [' +label_dict[col] + ']', size=14)
        
        ax.xaxis.set_minor_locator(mdates.YearLocator())
        ax.tick_params(top=False, right=True, direction="in")
    
        if same_ylim:
            ax.set_ylim(ylim)
    
    plt.subplots_adjust(wspace=0, hspace=0)
    fig.align_ylabels()
    

# Let's plot SPX and VIX cumulative returns with recession overlay
plot_cols = ['Temperature', 'pH_corrected', 'NO3_USF', 'PO4_USF', 'SiO4_USF']
y_label = ['°C', 'pH', 'µM', 'µM', 'µM']
no_of_rows = len(plot_cols)


plottimeseries2(plot_cols, y_label, no_of_rows, title='Integrated 100 m')
# Out:
# Temperature
# pH_corrected
# NO3_USF
# PO4_USF
# SiO4_USF

# %%
plot_cols = ['wind','u10', 'cdir', 'mtpr']
y_label = ['m $\mathrm{s}^{-1}$', 'm $\mathrm{s}^{-1}$', 'PAR', 'Precipitation']
no_of_rows = len(plot_cols)

plottimeseries2(plot_cols, y_label, no_of_rows, title='ERA5 data')
#plt.savefig("NewTimeSeriesPlots/TS3_ERA5.png")
# Out:
# wind
# u10
# cdir
# mtpr

# %%
#dat1 = CARIACO.groupby(CARIACO.index.year, dropna=False).apply(lambda x: x.std(skipna=False))
dat = CARIACO.groupby(CARIACO.index.year, dropna=False).std()

#plt.plot(dat

# %%
dat
# Out:
#       Unnamed: 0      cdww      iews      inss       mcc       mwp      si10  \
# date
# 1995    0.707107  0.000015  0.002276  0.004108  0.018121  0.017526  0.276337
# 1996    3.605551  0.000098  0.025491  0.016172  0.039409  0.452885  1.441720
# 1997    4.183300  0.000089  0.022946  0.013339  0.041276  0.321780  1.252100
# 1998    3.605551  0.000070  0.020843  0.012434  0.047329  0.339758  1.141252
# 1999    3.605551  0.000101  0.026071  0.016286  0.040213  0.505795  1.546620
# 2000    3.605551  0.000076  0.018773  0.011698  0.031188  0.421725  1.101152
# 2001    3.605551  0.000092  0.025015  0.015163  0.032657  0.412558  1.357795
# 2002    3.605551  0.000075  0.017695  0.011552  0.033401  0.268269  1.099001
# 2003    3.605551  0.000091  0.026928  0.015953  0.044982  0.304054  1.468598
# 2004    3.605551  0.000102  0.026556  0.017073  0.033939  0.505446  1.526872
# 2005    3.605551  0.000099  0.023926  0.016817  0.043229  0.402088  1.475191
# 2006    3.605551  0.000094  0.023573  0.014958  0.040195  0.316089  1.383882
# 2007    3.605551  0.000091  0.023717  0.015052  0.033542  0.285616  1.383419
# 2008    3.605551  0.000113  0.030091  0.018265  0.021525  0.300716  1.635313
# 2009    3.605551  0.000077  0.018499  0.011793  0.047212  0.321926  1.044841
# 2010    3.605551  0.000086  0.026560  0.015632  0.065093  0.557702  1.444497
# 2011    3.605551  0.000088  0.020970  0.014238  0.041739  0.380660  1.289279
# 2012    3.894440  0.000088  0.020282  0.013449  0.050378  0.252818  1.292093
# 2013    3.605551  0.000087  0.022390  0.014477  0.036617  0.368848  1.274187
# 2014    3.605551  0.000087  0.023216  0.014701  0.037772  0.295009  1.328754
# 2015    3.605551  0.000089  0.025247  0.014996  0.029982  0.278864  1.271621
# 2016    3.605551  0.000100  0.027681  0.016535  0.043319  0.369610  1.510529
# 2017    3.605551  0.000091  0.023303  0.014625  0.035169  0.387792  1.388110
# 2018    3.605551  0.000086  0.021454  0.013751  0.034876  0.385390  1.259182
# 2019    3.605551  0.000099  0.027817  0.016894  0.039160  0.360194  1.508013
# 2020    3.605551  0.000049  0.013286  0.008246  0.027655  0.310355  0.644307
# 2021    3.316625       NaN       NaN       NaN       NaN       NaN       NaN
#
#               sp       sst       t2m  ...   Chloro1    Cyano4    Diatom1  \
# date                                  ...
# 1995   65.760931  1.008009  0.600157  ...       NaN       NaN        NaN
# 1996  115.451583  1.102846  0.812642  ...  3.264007  1.112307  25.452065
# 1997  103.916871  1.464179  1.106062  ...  0.377580  0.741632  23.590474
# 1998   91.300310  1.566477  1.022048  ...  0.769558  1.568578  18.579881
# 1999  110.194766  1.705104  1.078466  ...  0.386603  1.332712  10.005398
# 2000  111.565403  1.484104  1.084889  ...  0.075689  1.283253   6.893842
# 2001  135.135225  1.607090  1.198346  ...       NaN       NaN        NaN
# 2002  110.661472  1.315708  0.952331  ...       NaN       NaN        NaN
# 2003  119.238471  1.807464  1.193983  ...       NaN       NaN        NaN
# 2004  131.966423  1.435394  0.922922  ...       NaN       NaN        NaN
# 2005   91.899981  1.161244  0.905441  ...       NaN       NaN        NaN
# 2006  107.625938  1.275626  0.952120  ...  0.474426  0.900653   6.559620
# 2007  106.216085  1.730367  1.061504  ...  0.591538  1.562514  22.015277
# 2008  111.219953  1.672282  1.166030  ...  0.584346  1.339945   7.134844
# 2009  107.533625  1.113673  0.912957  ...  0.515584  1.181842  10.499832
# 2010  102.509168  1.644920  0.972397  ...  0.545392  1.932878  23.628422
# 2011   86.923671  1.434819  1.044218  ...  0.441788  2.101632  26.264360
# 2012  115.178375  1.693958  1.191434  ...  0.626626  1.784807  63.812202
# 2013  101.690601  1.369102  0.955374  ...  0.082999  2.358328   4.614037
# 2014   92.843862  1.682132  1.112142  ...  6.823355  1.849542  76.694431
# 2015  104.386509  1.178572  0.905008  ...  0.131765  2.622657  15.762933
# 2016  145.227899  1.591500  1.056161  ...  0.231120  3.206827  15.145097
# 2017  116.136028  1.309691  0.990895  ...       NaN       NaN        NaN
# 2018  129.334475  1.556919  1.042634  ...       NaN       NaN        NaN
# 2019  125.051046  2.033495  1.386158  ...       NaN       NaN        NaN
# 2020   43.576424  0.658311  0.552483  ...       NaN       NaN        NaN
# 2021         NaN       NaN       NaN  ...       NaN       NaN        NaN
#
#         Mesh200   Mesh500  total_biomass  SeaWiFS_chla  MODIS_chla  \
# date
# 1995        NaN       NaN            NaN           NaN         NaN
# 1996        NaN       NaN            NaN           NaN         NaN
# 1997        NaN       NaN            NaN      0.345494         NaN
# 1998        NaN       NaN            NaN      0.508388         NaN
# 1999        NaN       NaN            NaN      0.580155         NaN
# 2000        NaN       NaN            NaN      0.693712         NaN
# 2001  11.767896  8.366061      20.133056      0.724456         NaN
# 2002   4.136947  2.428558       5.654536      0.852726    0.467512
# 2003   4.629826  2.666297       7.076978      1.012976    0.817275
# 2004   5.247526  3.220032       8.113063      0.494984    0.792679
# 2005   2.719647  1.983438       4.220955      0.521531    0.417541
# 2006   4.971800  3.657706       7.750667      0.440524    0.326802
# 2007   5.050044  3.256676       7.911306      0.772013    0.857702
# 2008   7.961004  4.196831      12.119337      0.458516    0.463656
# 2009   5.418861  4.490934       9.597279      0.410182    0.395104
# 2010   4.267194  3.056881       6.683225      0.952844    1.251347
# 2011   5.710055  2.502486       7.460758           NaN    0.584763
# 2012  10.925524  8.636654      18.382911           NaN    0.794873
# 2013   5.725678  3.996269       8.888176           NaN    0.715811
# 2014   7.111484  7.223143      13.664871           NaN    2.093756
# 2015   4.674825  3.046651       7.337792           NaN    0.750328
# 2016   3.960617  2.561342       6.078848           NaN    1.624749
# 2017        NaN       NaN            NaN           NaN    0.410392
# 2018        NaN       NaN            NaN           NaN    1.384024
# 2019        NaN       NaN            NaN           NaN    1.882292
# 2020        NaN       NaN            NaN           NaN    1.015553
# 2021        NaN       NaN            NaN           NaN    1.018458
#
#       Satellite_chla  diversity
# date
# 1995             NaN   0.177704
# 1996             NaN   0.844753
# 1997        0.345494   0.517277
# 1998        0.508388   0.655127
# 1999        0.580155   0.800482
# 2000        0.693712   0.717187
# 2001        0.724456   0.738681
# 2002        0.860795   0.629575
# 2003        0.817355   0.837164
# 2004        0.633341   0.840348
# 2005        0.466131   1.065361
# 2006        0.354066   1.140219
# 2007        0.812893   0.663630
# 2008        0.456040   0.903359
# 2009        0.404512   0.926620
# 2010        1.097410   0.872102
# 2011        0.584763   0.948568
# 2012        0.794873   0.398265
# 2013        0.715811   0.731724
# 2014        2.093756   0.845724
# 2015        0.750328   0.732208
# 2016        1.624749   0.807242
# 2017        0.410392        NaN
# 2018        1.384024        NaN
# 2019        1.882292        NaN
# 2020        1.015553        NaN
# 2021        1.018458        NaN
#
# [27 rows x 96 columns]

# %%
plt.plot(dat2.si10)
plt.show()

plt.plot(dat1.si10)
