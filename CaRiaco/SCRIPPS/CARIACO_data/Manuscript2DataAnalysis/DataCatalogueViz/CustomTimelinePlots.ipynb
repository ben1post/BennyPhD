# %%
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt

# %%
pd.__version__
# Out:
# '1.3.5'

# %%
CARIACO = xr.open_dataset("../annotatedDATA/CARIACO_merged_03.nc")

# %%
CARIACO
# Out:
# <xarray.Dataset>
# Dimensions:                       (time: 298)
# Coordinates:
#   * time                          (time) datetime64[ns] 1995-11-01 ... 2020-0...
# Data variables:
#     time_month                    (time) object ...
#     cdww                          (time) float64 ...
#     iews                          (time) float64 ...
#     inss                          (time) float64 ...
#     mcc                           (time) float64 ...
#     mwp                           (time) float64 ...
#     si10                          (time) float64 ...
#     sp                            (time) float64 ...
#     sst                           (time) float64 ...
#     t2m                           (time) float64 ...
#     tauoc                         (time) float64 ...
#     u10                           (time) float64 ...
#     ust                           (time) float64 ...
#     v10                           (time) float64 ...
#     v10n                          (time) float64 ...
#     vst                           (time) float64 ...
#     wind                          (time) float64 ...
#     cdir                          (time) float64 ...
#     e                             (time) float64 ...
#     ewss                          (time) float64 ...
#     i10fg                         (time) float64 ...
#     lsp                           (time) float64 ...
#     magss                         (time) float64 ...
#     mer                           (time) float64 ...
#     metss                         (time) float64 ...
#     mmtss                         (time) float64 ...
#     mntss                         (time) float64 ...
#     mtpr                          (time) float64 ...
#     nsss                          (time) float64 ...
#     sshf                          (time) int32 ...
#     tp                            (time) float64 ...
#     O2_ml_L                       (time) float64 ...
#     O2_umol_kg                    (time) float64 ...
#     NO3_UDO                       (time) float64 ...
#     PO4_UDO                       (time) float64 ...
#     SiO4_UDO                      (time) float64 ...
#     NH4_USF                       (time) float64 ...
#     NO2_USF                       (time) float64 ...
#     NO3_NO2_USF                   (time) float64 ...
#     PO4_USF                       (time) float64 ...
#     SiO4_USF                      (time) float64 ...
#     pH                            (time) float64 ...
#     Alkalinity_mol_kg             (time) float64 ...
#     Alkalinity_umol_kg            (time) float64 ...
#     TCO2                          (time) float64 ...
#     fCO2                          (time) float64 ...
#     pH_corrected                  (time) float64 ...
#     TCO2_corrected                (time) float64 ...
#     fCO2_corrected                (time) float64 ...
#     Salinity_bottles              (time) float64 ...
#     Salinity_CTD                  (time) float64 ...
#     Temperature                   (time) float64 ...
#     Sigma_t                       (time) float64 ...
#     TPP                           (time) float64 ...
#     PIP                           (time) float64 ...
#     POC_ug_kg                     (time) float64 ...
#     PON_ug_kg                     (time) float64 ...
#     POC_ug_L                      (time) float64 ...
#     PN_ug_L                       (time) float64 ...
#     C_N_particulate               (time) float64 ...
#     DON                           (time) float64 ...
#     DOP                           (time) float64 ...
#     DOC                           (time) float64 ...
#     TOC                           (time) float64 ...
#     PrimaryProductivity           (time) float64 ...
#     Chlorophyll                   (time) float64 ...
#     Phaeopigments                 (time) float64 ...
#     Total_Prokaryotes             (time) float64 ...
#     Bact_Biomass_mgC_m3           (time) float64 ...
#     Bact_Biomass_uMC              (time) float64 ...
#     NO3_USF                       (time) float64 ...
#     NO3_merged                    (time) float64 ...
#     PO4_merged                    (time) float64 ...
#     SiO4_merged                   (time) float64 ...
#     temp_5                        (time) float64 ...
#     temp_15                       (time) float64 ...
#     temp_25                       (time) float64 ...
#     temp_75                       (time) float64 ...
#     Isopycnal_21                  (time) float64 ...
#     MLD_potemp                    (time) float64 ...
#     SR_COCCOLITHOPHORIDS          (time) float64 ...
#     SR_CYANOBACTERIA              (time) float64 ...
#     SR_DIATOMS                    (time) float64 ...
#     SR_DINOFLAGELLATES            (time) float64 ...
#     SR_OTHERS                     (time) float64 ...
#     species_richness              (time) float64 ...
#     counts_int_COCCOLITHOPHORIDS  (time) float64 ...
#     counts_int_DIATOMS            (time) float64 ...
#     counts_int_DINOFLAGELLATES    (time) float64 ...
#     counts_int_CYANOBACTERIA      (time) float64 ...
#     counts_int_OTHERS             (time) float64 ...
#     counts_int_NANOFLAGELLATES    (time) float64 ...
#     Mesh200                       (time) float64 ...
#     Mesh500                       (time) float64 ...
#     total_biomass                 (time) float64 ...
#     SeaWiFS_chla                  (time) float64 ...
#     MODIS_chla                    (time) float64 ...
#     Satellite_chla                (time) float64 ...
# Attributes:
#     creator:        Benjamin Post
#     creation date:  2022-01-25

# %% [markdown]
# # Collect Plot functions for Data Catalogue
#
# what do i want to do? -> show general trends and yearly dynamics
#
# plots to do it:
# - colormap year month
# - time series with linear trend
# - deviation from mean

# %% [markdown]
# ## 2 ways to present:
# - do one type of plot for all data
# - all 3 plots per data type
#
# 2nd option is better!

# %% [markdown]
# ## colormap

# %%
#chl_pd.values
#from matplotlib.pyplot import figure
def plot_yearmonth_cmap(ax, data, bottom0=False, negativemax=False):
    
    data_pd = data.to_dataframe()
    
    dat_pivot = (data_pd.assign(year=data_pd.index.year, month=data_pd.index.month)
      .pivot_table(index='year', columns='month', values=data.name, dropna=False)
    )

    if negativemax == True:
        c = ax.pcolormesh(dat_pivot, cmap='cividis_r')
    else:
        c = ax.pcolormesh(dat_pivot, cmap='cividis')
        
    cbar = plt.colorbar(c, ax=ax, aspect=50)
    
    cbar.set_label(data.attrs['long_name'] + ' ' + data.attrs['units'])
    if bottom0 == True:
        c.set_clim(0)
    else:
        pass
    
    ax.set_yticks(np.arange(0,len(dat_pivot.index.values)))
    ax.set_yticklabels(dat_pivot.index.values)
    ax.set_ylabel('Years')
    
    ax.set_xticks(np.arange(0,12)+1-0.5)
    ax.set_xticklabels(np.arange(1,13))
    ax.set_xlabel('Months')

    return ax

# %% [markdown]
# ## trends over time series
#
# - plot regimes somehow? rolling yearly mean?

# %%
import matplotlib.dates as mdates

def plot_timeseries_withtrend(ax, data, bottom0=False, rev_y=False):

    ax.xaxis.set_minor_locator(mdates.YearLocator())
    
    ax.grid(True,which='both', color='lightgrey')
    ax.tick_params(top=False, right=True, direction="in")
    
    #plot time series
    ax.plot(data.time, data, c='black', lw=0.5, zorder=0)
    ax.scatter(data.time, data, c='black', marker='x', zorder=0)
    
    if bottom0 == True:
        ax.set_ylim(bottom=0)
        
    # plot linear reg
    idx = np.isfinite(data.values)
    fit = np.polyfit(mdates.date2num(data.time[idx]), data.values[idx].flatten(), 1)
    fit_fn = np.poly1d(fit)
    
    ax.plot(data.time, fit_fn(mdates.date2num(data.time)), label='linear reg', zorder=5)
    
    if rev_y == True:
        ax.invert_yaxis()
    
    return ax

# %% [markdown]
# ## deviation from mean

# %%
yearly_mean = CARIACO.DON.groupby(CARIACO.DON.time.dt.year).mean()
yearly_mean

years = np.unique(CARIACO.DON.time.astype('datetime64[Y]'))
years
# Out:
# array(['1995-01-01T00:00:00.000000000', '1996-01-01T00:00:00.000000000',
#        '1997-01-01T00:00:00.000000000', '1998-01-01T00:00:00.000000000',
#        '1999-01-01T00:00:00.000000000', '2000-01-01T00:00:00.000000000',
#        '2001-01-01T00:00:00.000000000', '2002-01-01T00:00:00.000000000',
#        '2003-01-01T00:00:00.000000000', '2004-01-01T00:00:00.000000000',
#        '2005-01-01T00:00:00.000000000', '2006-01-01T00:00:00.000000000',
#        '2007-01-01T00:00:00.000000000', '2008-01-01T00:00:00.000000000',
#        '2009-01-01T00:00:00.000000000', '2010-01-01T00:00:00.000000000',
#        '2011-01-01T00:00:00.000000000', '2012-01-01T00:00:00.000000000',
#        '2013-01-01T00:00:00.000000000', '2014-01-01T00:00:00.000000000',
#        '2015-01-01T00:00:00.000000000', '2016-01-01T00:00:00.000000000',
#        '2017-01-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
def plot_deviationfrommean(ax, data, bottom0=False, rev_y=False):

    ax.xaxis.set_minor_locator(mdates.YearLocator())
    
    ax.grid(True,which='both', color='lightgrey')
    ax.tick_params(top=False, right=True, direction="in")
    
    #ax.plot(data.time, data, c='black', lw=0.5, zorder=0)
    
    yearly_mean = data.groupby(data.time.dt.year).mean()
    
    yearly_counts = data.groupby(data.time.dt.year).count()
    
    yearly_mean[yearly_counts<5] = np.nan
    
    years = np.unique(data.time.astype('datetime64[Y]'))

    dat_mean = np.nanmean(data.values)
    #plot time series
    #ax.bar(x=data.time, height=data-dat_mean, align='edge', bottom=dat_mean, width=7.5)#, width=1)
    
    ax.bar(x=years, height=yearly_mean-dat_mean, align='edge', bottom=dat_mean, width=365.1, alpha=0.5)#, width=1)

    ax.axhline(y=dat_mean)

    if bottom0 == True:
        ax.set_ylim(bottom=0)
    ax.set_xlim(years[0], years[len(years)-1])
    
    if rev_y == True:
        ax.invert_yaxis()
    
    return ax

# %% [markdown]
# # create large multiplots to export to PDF pages

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

def create_custom3data_panelpage(datasets, page=0, subset='FILL', bottom0=False):
    #mpl.use('pdf')

    #description = 'Page: %s, Subset: %s'%(page, subset)

    title_fontsize = 'large'
    fig = plt.figure(dpi=400, tight_layout=True)
    fig.set_size_inches(8.27*1.5, 11.27*1.5, forward=True)

    #plt.figtext(0.02, .999, description, fontsize = 'small')

    ax = np.zeros(6, dtype=object)
    gs = fig.add_gridspec(6, 3, height_ratios=[1,1,1,1,1,1],)
    ax[0] = fig.add_subplot(gs[:2, 0])
    ax[1] = fig.add_subplot(gs[0, 1:])
    ax[2] = fig.add_subplot(gs[1, 1:])

    ax[3] = fig.add_subplot(gs[2:4, 0])
    ax[4] = fig.add_subplot(gs[2, 1:])
    ax[5] = fig.add_subplot(gs[3, 1:])

    #ax[6] = fig.add_subplot(gs[4:6, 0])
    #ax[7] = fig.add_subplot(gs[4, 1:])
    #ax[8] = fig.add_subplot(gs[5, 1:])

    plot_yearmonth_cmap(ax[0], datasets[0], bottom0=bottom0)
    ax[0].set_title(datasets[0].name, fontsize = title_fontsize)
    plot_timeseries_withtrend(ax[1], datasets[0], bottom0=bottom0)
    attrs0 = datasets[0].attrs
    ax[1].set_title('Long name: %s, Source: %s, Subset: %s'%(attrs0['long_name'], attrs0['source'], attrs0['subset']))
    plot_deviationfrommean(ax[2], datasets[0], bottom0=bottom0)

    plot_yearmonth_cmap(ax[3], datasets[1], bottom0=bottom0, negativemax=True)
    ax[3].set_title(datasets[1].name, fontsize = title_fontsize)
    plot_timeseries_withtrend(ax[4], datasets[1], bottom0=bottom0, rev_y=True)
    attrs1 = datasets[1].attrs
    ax[4].set_title('Long name: %s, Source: %s, Subset: %s'%(attrs1['long_name'], attrs1['source'], attrs1['subset']))
    plot_deviationfrommean(ax[5], datasets[1], bottom0=bottom0, rev_y=True)

    #plot_yearmonth_cmap(ax[6], datasets[2], bottom0=bottom0)
    #ax[6].set_title(datasets[2].name, fontsize = title_fontsize)
    #plot_timeseries_withtrend(ax[7], datasets[2], bottom0=bottom0)
    #attrs1 = datasets[2].attrs
    #ax[7].set_title('Long name: %s, Source: %s, Subset: %s'%(attrs1['long_name'], attrs1['source'], attrs1['subset']))
    #plot_deviationfrommean(ax[8], datasets[2], bottom0=bottom0)
    plt.show()
    fig.savefig("CustomTimeSeriesPlot_1_Upwelling.pdf")
    return ax

# %% [raw]
# datalist = list(CARIACO.data_vars)[0:6]
#
# #for i in range(len(datalist)):
# #    CARIACO[datalist][datalist[i]]
#
# for slicelist in zip(*(iter(datalist),) * 3):
#     datlist = []
#     for val in slicelist:
#         datlist.append(CARIACO[val])
#
# datlist[1].name

# %%
CARIACO.data_vars
# Out:
# Data variables:
#     time_month                    (time) object '11-1995' ... '01-2017'
#     cdww                          (time) float64 0.0009123 ... 0.0009537
#     iews                          (time) float64 -0.05435 -0.05757 ... -0.06034
#     inss                          (time) float64 -0.02569 -0.0315 ... -0.03415
#     mcc                           (time) float64 0.0971 0.07148 ... 0.1155
#     mwp                           (time) float64 5.125 5.149 ... 4.967 5.255
#     si10                          (time) float64 6.114 6.505 ... 7.692 6.772
#     sp                            (time) float64 1.011e+05 ... 1.013e+05
#     sst                           (time) float64 300.7 299.3 ... 300.4 298.1
#     t2m                           (time) float64 299.7 298.9 ... 299.5 298.0
#     tauoc                         (time) float64 0.9785 0.9752 ... 0.9584 0.9724
#     u10                           (time) float64 -5.306 -5.446 ... -6.838 -5.638
#     ust                           (time) float64 -0.04214 -0.04413 ... -0.04574
#     v10                           (time) float64 -2.556 -3.062 ... -3.034 -3.3
#     v10n                          (time) float64 -2.637 -3.117 ... -3.089 -3.32
#     vst                           (time) float64 -0.02757 -0.03264 ... -0.03543
#     wind                          (time) float64 4.537 4.765 ... 5.656 4.975
#     cdir                          (time) int32 19084480 18168832 ... 18562832
#     e                             (time) float64 -0.003558 ... -0.002196
#     ewss                          (time) float64 -5.507e+03 ... -5.803e+03
#     i10fg                         (time) float64 8.638 8.923 ... 10.48 9.065
#     lsp                           (time) float64 0.0002081 ... 0.0001184
#     magss                         (time) float64 6.192e+03 ... 6.829e+03
#     mer                           (time) float64 -4.118e-05 ... -2.541e-05
#     metss                         (time) float64 -0.06372 -0.06729 ... -0.06713
#     mmtss                         (time) float64 0.07169 0.07819 ... 0.07905
#     mntss                         (time) float64 -0.02875 -0.03522 ... -0.03676
#     mtpr                          (time) float64 1.188e-05 ... 2.491e-06
#     nsss                          (time) float64 -2.489e+03 ... -3.18e+03
#     sshf                          (time) int32 -668755 -253528 ... -759335 5848
#     tp                            (time) float64 0.001027 ... 0.0002142
#     O2_ml_L                       (time) float64 4.067 3.439 ... 3.642 3.194
#     O2_umol_kg                    (time) float64 177.3 149.8 ... 158.7 139.1
#     NO3_UDO                       (time) float64 0.9218 3.095 7.512 ... nan nan
#     PO4_UDO                       (time) float64 0.06163 0.2114 ... nan nan
#     SiO4_UDO                      (time) float64 2.127 3.869 4.868 ... nan nan
#     NH4_USF                       (time) float64 nan nan nan ... 0.1463 0.4244
#     NO2_USF                       (time) float64 nan nan nan ... 0.1118 0.09568
#     NO3_NO2_USF                   (time) float64 nan nan nan ... nan 3.183 5.193
#     PO4_USF                       (time) float64 nan nan nan ... 0.2175 0.3763
#     SiO4_USF                      (time) float64 nan nan nan ... nan 2.206 2.49
#     pH                            (time) float64 nan 8.006 7.984 ... 7.984 7.942
#     Alkalinity_mol_kg             (time) float64 0.002407 0.002409 ... 0.002211
#     Alkalinity_umol_kg            (time) float64 2.407e+03 ... 2.211e+03
#     TCO2                          (time) float64 nan 2.108e+03 ... 1.962e+03
#     fCO2                          (time) float64 nan 433.7 444.5 ... 484.7 452.6
#     pH_corrected                  (time) float64 nan 8.011 7.989 ... 7.996 7.953
#     TCO2_corrected                (time) float64 nan 2.105e+03 ... 1.956e+03
#     fCO2_corrected                (time) float64 nan 427.5 438.1 ... 469.8 439.6
#     Salinity_bottles              (time) float64 36.76 nan 36.88 ... 36.81 36.84
#     Salinity_CTD                  (time) float64 nan 36.86 nan ... 36.81 36.86
#     Temperature                   (time) float64 25.32 23.69 ... 24.84 22.42
#     Sigma_t                       (time) float64 24.55 25.14 ... 24.74 25.51
#     TPP                           (time) float64 nan nan nan ... nan 38.35 65.58
#     PIP                           (time) float64 nan nan nan ... nan 11.37 27.69
#     POC_ug_kg                     (time) float64 nan 48.45 82.01 ... 111.3 155.5
#     PON_ug_kg                     (time) float64 nan 9.04 14.48 ... 11.49 26.49
#     POC_ug_L                      (time) float64 nan 6.327 5.684 ... 11.21 7.015
#     PN_ug_L                       (time) float64 nan 47.28 80.03 ... 108.7 151.8
#     C_N_particulate               (time) float64 nan 8.822 14.13 ... 11.22 25.86
#     DON                           (time) float64 nan nan nan nan ... nan nan nan
#     DOP                           (time) float64 nan nan nan nan ... nan nan nan
#     DOC                           (time) float64 78.71 nan 81.53 ... 73.47 65.76
#     TOC                           (time) float64 nan nan nan ... nan 79.53 281.3
#     PrimaryProductivity           (time) float64 nan 0.4827 2.057 ... 0.59 nan
#     Chlorophyll                   (time) float64 0.1793 0.1151 ... 0.261 0.4037
#     Phaeopigments                 (time) float64 0.27 0.1636 ... 0.317 0.3948
#     Total_Prokaryotes             (time) float64 nan 0.7003 ... 0.5464 2.753
#     Bact_Biomass_mgC_m3           (time) float64 nan 2.132 9.929 ... 1.783 8.983
#     Bact_Biomass_uMC              (time) float64 nan 0.1776 ... 0.1486 0.7486
#     NO3_USF                       (time) float64 nan nan nan ... nan 3.071 5.097
#     NO3_merged                    (time) float64 0.9218 3.095 ... 3.071 5.097
#     PO4_merged                    (time) float64 0.06163 0.2114 ... 0.3763
#     SiO4_merged                   (time) float64 2.127 3.869 ... 2.206 2.49
#     temp_5                        (time) float64 27.51 25.49 ... 26.6 24.65
#     temp_15                       (time) float64 27.47 25.49 ... 26.55 24.35
#     temp_25                       (time) float64 27.4 25.36 24.0 ... 26.5 24.26
#     temp_75                       (time) float64 25.7 24.3 23.11 ... 25.69 23.03
#     Isopycnal_21                  (time) float64 131.0 115.0 ... 109.0 75.0
#     MLD_potemp                    (time) float64 23.0 21.0 nan ... nan 57.0 34.0
#     SR_COCCOLITHOPHORIDS          (time) float64 5.0 0.0 3.0 6.0 ... nan 9.0 5.0
#     SR_CYANOBACTERIA              (time) float64 4.0 1.0 6.0 3.0 ... nan 2.0 1.0
#     SR_DIATOMS                    (time) float64 64.0 59.0 53.0 ... 53.0 38.0
#     SR_DINOFLAGELLATES            (time) float64 18.0 18.0 12.0 ... 14.0 17.0
#     SR_OTHERS                     (time) float64 0.0 0.0 1.0 1.0 ... nan 2.0 0.0
#     species_richness              (time) float64 91.0 78.0 75.0 ... 80.0 61.0
#     counts_int_COCCOLITHOPHORIDS  (time) float64 0.04638 0.0 ... 0.004106
#     counts_int_DIATOMS            (time) float64 0.3234 0.6917 ... 0.1542 0.1337
#     counts_int_DINOFLAGELLATES    (time) float64 0.07419 0.3235 ... 0.01125
#     counts_int_CYANOBACTERIA      (time) float64 0.1715 0.3975 ... 0.001216
#     counts_int_OTHERS             (time) float64 0.0 0.0 0.02898 ... 0.01296 0.0
#     counts_int_NANOFLAGELLATES    (time) float64 201.4 327.0 ... 254.4 219.6
#     Mesh200                       (time) float64 nan nan nan ... nan 4.07 3.107
#     Mesh500                       (time) float64 nan nan nan ... 1.266 0.9665
#     total_biomass                 (time) float64 nan nan nan ... nan 5.336 4.074

# %%
datas = [CARIACO.si10, CARIACO.Isopycnal_21]#, CARIACO.temp_25]

datas2 = [CARIACO.sst, CARIACO.temp_25]#, CARIACO.temp_25]

# %%
create_custom3data_panelpage(datas)
# Out:
# array([<AxesSubplot:title={'center':'si10'}, xlabel='Months', ylabel='Years'>,
#        <AxesSubplot:title={'center':'Long name: 10 metre wind speed, Source: ERA5, Subset: wind speed'}>,
#        <AxesSubplot:>,
#        <AxesSubplot:title={'center':'Isopycnal_21'}, xlabel='Months', ylabel='Years'>,
#        <AxesSubplot:title={'center':'Long name: 21° Isotherm, Source: ctd, Subset: physical'}>,
#        <AxesSubplot:>], dtype=object)

# %% [markdown]
# # CREATE MULTIPAGE PDF

# %%
import datetime
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.pyplot as plt

# Create the PdfPages object to which we will save the pages:
# The with statement makes sure that the PdfPages object is closed properly at
# the end of the block, even if an Exception occurs.
with PdfPages('CARIACO_full_data.pdf') as pdf:

    
    data2plotlist = []
    for val in list(CARIACO.data_vars):
        if val in ['time_month',]:
            print('passing ', val)
        else:
            print('adding', val)
            data2plotlist.append(val)
    
    for slicelist in zip(*(iter(data2plotlist),) * 3):
        datlist = []
        for val in slicelist:
                datlist.append(CARIACO[val])
        plt.title(datlist)
        print("creating plots", datlist)
        create_3data_panelpage(datlist)
        pdf.savefig()  # saves the current figure into a pdf page
        plt.close()

    # We can also set the file's metadata via the PdfPages object:
    d = pdf.infodict()
    d['Title'] = 'CARIACO data catalogue'
    d['Author'] = 'Benjamin Post'
    d['Subject'] = 'Overview and preliminary analysis of CARIACO time series data from in-situ, ERA5 climate model and SeaWiFs satellite data'
    d['Keywords'] = 'Cariaco Venezuela Ocean Time Series Phytoplankton ERA5'
    d['CreationDate'] = datetime.datetime(2021, 12, 17)
    d['ModDate'] = datetime.datetime.today()
    
    pdf.close()
    print("PDF DONE!")
# Out:
# passing  time_month
# adding cdww
# adding iews
# adding inss
# adding mcc
# adding mwp
# adding si10
# adding sp
# adding sst
# adding t2m
# adding tauoc
# adding u10
# adding ust
# adding v10
# adding v10n
# adding vst
# adding wind
# adding cdir
# adding e
# adding ewss
# adding i10fg
# adding lsp
# adding magss
# adding mer
# adding metss
# adding mmtss
# adding mntss
# adding mtpr
# adding nsss
# adding sshf
# adding tp
# adding O2_ml_L
# adding O2_umol_kg
# adding NO3_UDO
# adding PO4_UDO
# adding SiO4_UDO
# adding NH4_USF
# adding NO2_USF
# adding NO3_NO2_USF
# adding PO4_USF
# adding SiO4_USF
# adding pH
# adding Alkalinity_mol_kg
# adding Alkalinity_umol_kg
# adding TCO2
# adding fCO2
# adding pH_corrected
# adding TCO2_corrected
# adding fCO2_corrected
# adding Salinity_bottles
# adding Salinity_CTD
# adding Temperature
# adding Sigma_t
# adding TPP
# adding PIP
# adding POC_ug_kg
# adding PON_ug_kg
# adding POC_ug_L
# adding PN_ug_L
# adding C_N_particulate
# adding DON
# adding DOP
# adding DOC
# adding TOC
# adding PrimaryProductivity
# adding Chlorophyll
# adding Phaeopigments
# adding Total_Prokaryotes
# adding Bact_Biomass_mgC_m3
# adding Bact_Biomass_uMC
# adding NO3_USF
# adding NO3_merged
# adding PO4_merged
# adding SiO4_merged
# adding temp_5
# adding temp_15
# adding temp_25
# adding temp_75
# adding Isopycnal_21
# adding MLD_potemp
# adding SR_COCCOLITHOPHORIDS
# adding SR_CYANOBACTERIA
# adding SR_DIATOMS
# adding SR_DINOFLAGELLATES
# adding SR_OTHERS
# adding species_richness
# adding counts_int_COCCOLITHOPHORIDS
# adding counts_int_DIATOMS
# adding counts_int_DINOFLAGELLATES
# adding counts_int_CYANOBACTERIA
# adding counts_int_OTHERS
# adding counts_int_NANOFLAGELLATES
# adding Mesh200
# adding Mesh500
# adding total_biomass
# creating plots [<xarray.DataArray 'cdww' (time: 256)>
# array([0.000912, 0.000934, 0.000979, ..., 0.000817, 0.001017, 0.000954])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  Coefficient of drag with waves
#     units:      dimensionless
#     data_name:  coefficient_of_drag_with_waves
#     source:     ERA5
#     subset:     waves, <xarray.DataArray 'iews' (time: 256)>
# array([-0.054353, -0.057572, -0.068143, ..., -0.031168, -0.090498, -0.060337])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  Instantaneous eastward turbulent surface stress
#     units:      N m**-2
#     data_name:  instantaneous_eastward_turbulent_surface_stress
#     source:     ERA5
#     subset:     wind stress, <xarray.DataArray 'inss' (time: 256)>
# array([-0.025692, -0.031501, -0.037201, ..., -0.011265, -0.039022, -0.034147])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  Instantaneous northward turbulent surface stress
#     units:      N m**-2
#     data_name:  instantaneous_northward_turbulent_surface_stress
#     source:     ERA5
#     subset:     wind stress]
# creating plots [<xarray.DataArray 'mcc' (time: 256)>
# array([0.097103, 0.071477, 0.076384, ..., 0.145041, 0.164576, 0.11548 ])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  Medium cloud cover
#     units:      (0 - 1)
#     data_name:  medium_cloud_cover
#     source:     ERA5
#     subset:     radiation, <xarray.DataArray 'mwp' (time: 256)>
# array([5.124629, 5.149414, 5.239093, ..., 5.217184, 4.967056, 5.255037])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  Mean wave period
#     units:      s
#     data_name:  mean_wave_period
#     source:     ERA5
#     subset:     waves, <xarray.DataArray 'si10' (time: 256)>
# array([6.113998, 6.504798, 7.016142, ..., 4.647686, 7.692372, 6.772333])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  10 metre wind speed
#     units:      m s**-1
#     data_name:  10m_wind_speed
#     source:     ERA5
#     subset:     wind speed]
# creating plots [<xarray.DataArray 'sp' (time: 256)>
# array([101075.125, 101168.125, 101168.81 , ..., 100908.19 , 101169.25 ,
#        101298.25 ])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  Surface pressure
#     units:      Pa
#     data_name:  surface_pressure
#     source:     ERA5
#     subset:     misc, <xarray.DataArray 'sst' (time: 256)>
# array([300.71152, 299.28598, 298.53207, ..., 301.82358, 300.37393, 298.0976 ])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  Sea surface temperature
#     units:      K
#     data_name:  sea_surface_temperature
#     source:     ERA5
#     subset:     temperature, <xarray.DataArray 't2m' (time: 256)>
# array([299.72668, 298.87793, 298.0664 , ..., 300.6626 , 299.49316, 297.97302])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  2 metre temperature
#     units:      K
#     data_name:  2m_temperature
#     source:     ERA5
#     subset:     temperature]
# creating plots [<xarray.DataArray 'tauoc' (time: 256)>
# array([0.978549, 0.975202, 0.967328, ..., 0.99074 , 0.958393, 0.972382])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  Normalized stress into ocean
#     units:      dimensionless
#     data_name:  normalized_stress_into_ocean
#     source:     ERA5
#     subset:     wind stress, <xarray.DataArray 'u10' (time: 256)>
# array([-5.305753, -5.446028, -5.860445, ..., -3.421169, -6.838108, -5.63767 ])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  10 metre U wind component
#     units:      m s**-1
#     data_name:  10m_u_component_of_wind
#     source:     ERA5
#     subset:     wind speed, <xarray.DataArray 'ust' (time: 256)>
# array([-0.042138, -0.044134, -0.05014 , ..., -0.025179, -0.064258, -0.045739])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  U-component stokes drift
#     units:      m s**-1
#     data_name:  u_component_stokes_drift
#     source:     ERA5
#     subset:     misc]
# creating plots [<xarray.DataArray 'v10' (time: 256)>
# array([-2.556126, -3.062268, -3.330804, ..., -1.329881, -3.033874, -3.300313])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  10 metre V wind component
#     units:      m s**-1
#     data_name:  10m_v_component_of_wind
#     source:     ERA5
#     subset:     wind speed, <xarray.DataArray 'v10n' (time: 256)>
# array([-2.636688, -3.117189, -3.385815, ..., -1.389954, -3.088854, -3.319675])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  Neutral wind at 10 m v-component
#     units:      m s**-1
#     data_name:  10m_v_component_of_neutral_wind
#     source:     ERA5
#     subset:     wind speed, <xarray.DataArray 'vst' (time: 256)>
# array([-0.027571, -0.032637, -0.037558, ..., -0.014331, -0.036905, -0.035429])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  V-component stokes drift
#     units:      m s**-1
#     data_name:  v_component_stokes_drift
#     source:     ERA5
#     subset:     misc]
# creating plots [<xarray.DataArray 'wind' (time: 256)>
# array([4.536621, 4.764648, 5.253656, ..., 3.486342, 5.655762, 4.974714])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  10 metre wind speed
#     units:      m s**-1
#     data_name:  ocean_surface_stress_equivalent_10m_neutral_wind_speed
#     source:     ERA5
#     subset:     wind stress, <xarray.DataArray 'cdir' (time: 256)>
# array([19084480, 18168832, 18737568, ..., 18782592, 17962656, 18562832],
#       dtype=int32)
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  Clear-sky direct solar radiation at surface
#     units:      J m**-2
#     data_name:  clear_sky_direct_solar_radiation_at_surface
#     source:     ERA5
#     subset:     radiation, <xarray.DataArray 'e' (time: 256)>
# array([-0.003558, -0.00257 , -0.002967, ..., -0.00323 , -0.004262, -0.002196])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  Evaporation
#     units:      m of water equivalent
#     data_name:  evaporation
#     source:     ERA5
#     subset:     evaporation]
# creating plots [<xarray.DataArray 'ewss' (time: 256)>
# array([-5506.953 , -5814.203 , -6851.992 , ..., -2815.3867, -8666.453 ,
#        -5802.801 ])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  Eastward turbulent surface stress
#     units:      N m**-2 s
#     data_name:  eastward_turbulent_surface_stress
#     source:     ERA5
#     subset:     wind stress, <xarray.DataArray 'i10fg' (time: 256)>
# array([ 8.638282,  8.922766,  9.613052, ...,  6.536376, 10.484583,  9.064997])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  Instantaneous 10 metre wind gust
#     units:      m s**-1
#     data_name:  instantaneous_10m_wind_gust
#     source:     ERA5
#     subset:     wind speed, <xarray.DataArray 'lsp' (time: 256)>
# array([2.080501e-04, 5.609891e-05, 6.571367e-05, ..., 1.462731e-03,
#        2.542901e-04, 1.184140e-04])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  Large-scale precipitation
#     units:      m
#     data_name:  large_scale_precipitation
#     source:     ERA5
#     subset:     precipitation]
# creating plots [<xarray.DataArray 'magss' (time: 256)>
# array([6192.3228, 6760.856 , 7976.0273, ..., 3508.9084, 9587.145 , 6829.465 ])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  Magnitude of turbulent surface stress
#     units:      N m**-2 s
#     data_name:  magnitude_of_turbulent_surface_stress
#     source:     ERA5
#     subset:     wind stress, <xarray.DataArray 'mer' (time: 256)>
# array([-4.118208e-05, -2.975033e-05, -3.433753e-05, ..., -3.738159e-05,
#        -4.933545e-05, -2.541090e-05])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  Mean evaporation rate
#     units:      kg m**-2 s**-1
#     data_name:  mean_evaporation_rate
#     source:     ERA5
#     subset:     evaporation, <xarray.DataArray 'metss' (time: 256)>
# array([-0.06372 , -0.067293, -0.079299, ..., -0.032615, -0.100272, -0.067134])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  Mean eastward turbulent surface stress
#     units:      N m**-2
#     data_name:  mean_eastward_turbulent_surface_stress
#     source:     ERA5
#     subset:     wind stress]
# creating plots [<xarray.DataArray 'mmtss' (time: 256)>
# array([0.071691, 0.078194, 0.092283, ..., 0.040606, 0.110992, 0.07905 ])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  Mean magnitude of turbulent surface stress
#     units:      N m**-2
#     data_name:  mean_magnitude_of_turbulent_surface_stress
#     source:     ERA5
#     subset:     wind stress, <xarray.DataArray 'mntss' (time: 256)>
# array([-0.028754, -0.035218, -0.041197, ..., -0.011527, -0.042032, -0.036758])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  Mean northward turbulent surface stress
#     units:      N m**-2
#     data_name:  mean_northward_turbulent_surface_stress
#     source:     ERA5
#     subset:     wind stress, <xarray.DataArray 'mtpr' (time: 256)>
# array([1.188099e-05, 1.320477e-06, 1.670900e-06, ..., 4.605214e-05,
#        8.815612e-06, 2.491111e-06])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  Mean total precipitation rate
#     units:      kg m**-2 s**-1
#     data_name:  mean_total_precipitation_rate
#     source:     ERA5
#     subset:     precipitation]
# creating plots [<xarray.DataArray 'nsss' (time: 256)>
# array([-2488.6484, -3042.9258, -3556.2266, ...,  -991.7295, -3629.6016,
#        -3179.961 ])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  Northward turbulent surface stress
#     units:      N m**-2 s
#     data_name:  northward_turbulent_surface_stress
#     source:     ERA5
#     subset:     wind stress, <xarray.DataArray 'sshf' (time: 256)>
# array([-668755, -253528, -272642, ..., -611307, -759335,    5848], dtype=int32)
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  Surface sensible heat flux
#     units:      J m**-2
#     data_name:  surface_sensible_heat_flux
#     source:     ERA5
#     subset:     misc, <xarray.DataArray 'tp' (time: 256)>
# array([0.001027, 0.000115, 0.000143, ..., 0.003979, 0.000762, 0.000214])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  Total precipitation
#     units:      m
#     data_name:  total_precipitation
#     source:     ERA5
#     subset:     precipitation]
# creating plots [<xarray.DataArray 'O2_ml_L' (time: 256)>
# array([4.066699, 3.438551, 3.405264, ...,      nan, 3.642156, 3.194164])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  dissolved oxygen (average in ml/L)
#     units:      milliliters/liter (ml/L)
#     source:     niskin
#     subset:     chemical, <xarray.DataArray 'O2_umol_kg' (time: 256)>
# array([177.277571, 149.808482, 148.311869, ...,        nan, 158.746701,
#        139.116157])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  dissolved oxygen (average in μmol/kg)
#     units:      micromoles/kilogram (μmol/kg)
#     source:     niskin
#     subset:     chemical, <xarray.DataArray 'NO3_UDO' (time: 256)>
# array([0.921754, 3.094884, 7.511627, ...,      nan,      nan,      nan])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  nitrate UDO (average)
#     units:      micromolar (μM)
#     source:     niskin
#     subset:     chemical]
# creating plots [<xarray.DataArray 'PO4_UDO' (time: 256)>
# array([0.061626, 0.211427, 0.303838, ...,      nan,      nan,      nan])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  phosphate UDO (average)
#     units:      micromolar (μM)
#     source:     niskin
#     subset:     chemical, <xarray.DataArray 'SiO4_UDO' (time: 256)>
# array([2.127115, 3.868919, 4.868135, ...,      nan,      nan,      nan])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  silica UDO
#     units:      micromolar (μM)
#     source:     niskin
#     subset:     chemical, <xarray.DataArray 'NH4_USF' (time: 256)>
# array([     nan,      nan,      nan, ...,      nan, 0.146254, 0.424409])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  ammonia USF
#     units:      micromolar (μM)
#     source:     niskin
#     subset:     chemical]
# creating plots [<xarray.DataArray 'NO2_USF' (time: 256)>
# array([     nan,      nan,      nan, ...,      nan, 0.111837, 0.095684])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  nitrite USF
#     units:      micromolar (μM)
#     source:     niskin
#     subset:     chemical, <xarray.DataArray 'NO3_NO2_USF' (time: 256)>
# array([     nan,      nan,      nan, ...,      nan, 3.182947, 5.1926  ])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  nitrate plus nitrite USF
#     units:      micromolar (μM)
#     source:     niskin
#     subset:     chemical, <xarray.DataArray 'PO4_USF' (time: 256)>
# array([     nan,      nan,      nan, ...,      nan, 0.217531, 0.376325])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  phosphate USF
#     units:      micromolar (μM)
#     source:     niskin
#     subset:     chemical]
# creating plots [<xarray.DataArray 'SiO4_USF' (time: 256)>
# array([     nan,      nan,      nan, ...,      nan, 2.205576, 2.49049 ])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  silica USF
#     units:      micromolar (μM)
#     source:     niskin
#     subset:     chemical, <xarray.DataArray 'pH' (time: 256)>
# array([     nan, 8.006083, 7.98369 , ...,      nan, 7.984401, 7.941975])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  pH average total hydrogen (at 25 deg. C) no corrected for dye...
#     units:      ion scale (pH)
#     source:     niskin
#     subset:     chemical, <xarray.DataArray 'Alkalinity_mol_kg' (time: 256)>
# array([0.002407, 0.002409, 0.002416, ...,      nan, 0.002408, 0.002211])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  total alkalinity
#     units:      moles/kilogram (mol/kg)
#     source:     niskin
#     subset:     chemical]
# creating plots [<xarray.DataArray 'Alkalinity_umol_kg' (time: 256)>
# array([2406.53698 , 2408.630753, 2415.540441, ...,         nan, 2408.013356,
#        2210.686994])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  total alkalinity
#     units:      micromoles/kilogram (μmol/kg)
#     source:     niskin
#     subset:     chemical, <xarray.DataArray 'TCO2' (time: 256)>
# array([        nan, 2108.156082, 2127.096141, ...,         nan, 2119.984729,
#        1961.742196])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  total carbon dioxide in seawater (no corrected)
#     units:      micromoles/kilogram (μmol/kg)
#     source:     niskin
#     subset:     chemical, <xarray.DataArray 'fCO2' (time: 256)>
# array([       nan, 433.7006  , 444.546888, ...,        nan, 484.702249,
#        452.640979])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  fugacity of CO2 in sea water (no corrected)
#     units:      microatmospheres (μatm)
#     source:     niskin
#     subset:     chemical]
# creating plots [<xarray.DataArray 'pH_corrected' (time: 256)>
# array([     nan, 8.011147, 7.988897, ...,      nan, 7.995916, 7.952522])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  pH average total hydrogen (at 25 deg. C) corrected for dye im...
#     units:      ion scale (pH)
#     source:     niskin
#     subset:     chemical, <xarray.DataArray 'TCO2_corrected' (time: 256)>
# array([        nan, 2104.955459, 2123.999938, ...,         nan, 2113.321286,
#        1955.982573])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  total carbon dioxide in seawater (recalculated with corrected...
#     units:      micromoles/kilogram (μmol/kg)
#     source:     niskin
#     subset:     chemical, <xarray.DataArray 'fCO2_corrected' (time: 256)>
# array([       nan, 427.505182, 438.124905, ...,        nan, 469.753037,
#        439.571026])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  fugacity of total carbon dioxide in seawate recalculated
#     units:      microatmospheres (μatm)
#     source:     niskin
#     subset:     chemical]
# creating plots [<xarray.DataArray 'Salinity_bottles' (time: 256)>
# array([36.762457,       nan, 36.884552, ...,       nan, 36.809323, 36.840042])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  salinity from salinometer
#     units:      PSU (PSU)
#     source:     niskin
#     subset:     physical, <xarray.DataArray 'Salinity_CTD' (time: 256)>
# array([      nan, 36.856086,       nan, ...,       nan, 36.808311, 36.862226])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  salinity from CTD
#     units:      PSU (PSU)
#     source:     niskin
#     subset:     physical, <xarray.DataArray 'Temperature' (time: 256)>
# array([25.322847, 23.687804, 22.633137, ...,       nan, 24.843858, 22.420057])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  temperature from CTD ITS-90 scale
#     units:      degrees Celsius (degC (°C))
#     source:     niskin
#     subset:     physical]
# creating plots [<xarray.DataArray 'Sigma_t' (time: 256)>
# array([24.545149, 25.13623 , 25.465645, ...,       nan, 24.744768, 25.505296])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  density
#     units:      kilograms/meter^3 (Kg/m^3)
#     source:     niskin
#     subset:     physical, <xarray.DataArray 'TPP' (time: 256)>
# array([      nan,       nan,       nan, ...,       nan, 38.349515, 65.576073])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  total particulate phosphorus
#     units:      nanomolar (nM)
#     source:     niskin
#     subset:     biological, <xarray.DataArray 'PIP' (time: 256)>
# array([      nan,       nan,       nan, ...,       nan, 11.365665, 27.688021])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  particulate inorganic phosphorus
#     units:      nanomolar (nM)
#     source:     niskin
#     subset:     biological]
# creating plots [<xarray.DataArray 'POC_ug_kg' (time: 256)>
# array([       nan,  48.445823,  82.009841, ...,        nan, 111.345486,
#        155.503127])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  particulate organic carbon
#     units:      micrograms/liter (μg/kg)
#     source:     niskin
#     subset:     biological, <xarray.DataArray 'PON_ug_kg' (time: 256)>
# array([      nan,  9.040385, 14.477669, ...,       nan, 11.493961, 26.493655])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  particulate organic nitrogen
#     units:      micrograms/liter (μg/kg)
#     source:     niskin
#     subset:     biological, <xarray.DataArray 'POC_ug_L' (time: 256)>
# array([      nan,  6.326811,  5.683677, ...,       nan, 11.21256 ,  7.015101])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  particulate organic carbon
#     units:      micrograms/liter (μg/L)
#     source:     niskin
#     subset:     biological]
# creating plots [<xarray.DataArray 'PN_ug_L' (time: 256)>
# array([       nan,  47.278055,  80.033012, ...,        nan, 108.661605,
#        151.754712])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  particulate organic nitrogen
#     units:      micrograms/liter (μg/L)
#     source:     niskin
#     subset:     biological, <xarray.DataArray 'C_N_particulate' (time: 256)>
# array([      nan,  8.822474, 14.128688, ...,       nan, 11.216901, 25.855061])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  carbon to nitrogen ratio of particulate C to N
#     units:      mole/mole (mol/mol)
#     source:     niskin
#     subset:     biological, <xarray.DataArray 'DON' (time: 256)>
# array([nan, nan, nan, ..., nan, nan, nan])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  dissolved organic nitrogen USF
#     units:      micromolar (μM)
#     source:     niskin
#     subset:     biological]
# creating plots [<xarray.DataArray 'DOP' (time: 256)>
# array([nan, nan, nan, ..., nan, nan, nan])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  dissolved organic phosporus USF
#     units:      micromolar (μM)
#     source:     niskin
#     subset:     biological, <xarray.DataArray 'DOC' (time: 256)>
# array([78.70598 ,       nan, 81.525672, ...,       nan, 73.470299, 65.757031])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  dissolved organic carbon
#     units:      micromolar (μM)
#     source:     niskin
#     subset:     biological, <xarray.DataArray 'TOC' (time: 256)>
# array([       nan,        nan,        nan, ...,        nan,  79.53464 ,
#        281.338842])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  total organic carbon
#     units:      micromolar (μM)
#     source:     niskin
#     subset:     biological]
# creating plots [<xarray.DataArray 'PrimaryProductivity' (time: 256)>
# array([     nan, 0.482692, 2.056931, ...,      nan, 0.589989,      nan])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  primary production
#     units:      milligrams Carbon/meter^3/hour (mgC/m^3/hr)
#     source:     niskin
#     subset:     biological, <xarray.DataArray 'Chlorophyll' (time: 256)>
# array([0.179305, 0.115095, 0.582576, ...,      nan, 0.260988, 0.403719])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  chlorophyll a
#     units:      milligrams/meter^3 (mg/m^3)
#     source:     niskin
#     subset:     biological, <xarray.DataArray 'Phaeopigments' (time: 256)>
# array([0.270035, 0.163628, 0.345171, ...,      nan, 0.317015, 0.394783])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  phaeopigment
#     units:      milligrams/meter^3 (mg/m^3)
#     source:     niskin
#     subset:     biological]
# creating plots [<xarray.DataArray 'Total_Prokaryotes' (time: 256)>
# array([     nan, 0.700285, 3.042905, ...,      nan, 0.546394, 2.753353])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  number of prokaryotes cells
#     units:      (cells/L )10^8 ((cells_x_10^8/L))
#     source:     niskin
#     subset:     biological, <xarray.DataArray 'Bact_Biomass_mgC_m3' (time: 256)>
# array([     nan, 2.131909, 9.928947, ...,      nan, 1.782674, 8.983241])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  bacterial biomass (mgC/m^3)
#     units:      milligrams Carbon/meter^3 (mgC/m^3)
#     source:     niskin
#     subset:     biological, <xarray.DataArray 'Bact_Biomass_uMC' (time: 256)>
# array([     nan, 0.17765 , 0.827412, ...,      nan, 0.148559, 0.748589])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  bacterial biomass (μMC)
#     units:      microMolar Carbon (μMC)
#     source:     niskin
#     subset:     biological]
# creating plots [<xarray.DataArray 'NO3_USF' (time: 256)>
# array([     nan,      nan,      nan, ...,      nan, 3.071111, 5.096916])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  XXX
#     units:      XX
#     source:     niskin
#     subset:     chemical, <xarray.DataArray 'NO3_merged' (time: 256)>
# array([0.921754, 3.094884, 7.511627, ...,      nan, 3.071111, 5.096916])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  XXX
#     units:      XX
#     source:     niskin
#     subset:     chemical, <xarray.DataArray 'PO4_merged' (time: 256)>
# array([0.061626, 0.211427, 0.303838, ...,      nan, 0.217531, 0.376325])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  XXX
#     units:      XX
#     source:     niskin
#     subset:     chemical]
# creating plots [<xarray.DataArray 'SiO4_merged' (time: 256)>
# array([2.127115, 3.868919, 4.868135, ...,      nan, 2.205576, 2.49049 ])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  XXX
#     units:      XX
#     source:     niskin
#     subset:     chemical, <xarray.DataArray 'temp_5' (time: 256)>
# array([27.5055  , 25.489   , 24.443   , ...,       nan, 26.5985  , 24.648667])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  XXX
#     units:      °C
#     source:     ctd
#     subset:     physical, <xarray.DataArray 'temp_15' (time: 256)>
# array([27.470143, 25.48975 , 24.155286, ...,       nan, 26.553786, 24.352   ])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  XXX
#     units:      °C
#     source:     ctd
#     subset:     physical]
# creating plots [<xarray.DataArray 'temp_25' (time: 256)>
# array([27.395182, 25.363308, 24.0025  , ...,       nan, 26.495083, 24.263478])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  XXX
#     units:      °C
#     source:     ctd
#     subset:     physical, <xarray.DataArray 'temp_75' (time: 256)>
# array([25.702556, 24.299974, 23.114243, ...,       nan, 25.687324, 23.030534])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  XXX
#     units:      °C
#     source:     ctd
#     subset:     physical, <xarray.DataArray 'Isopycnal_21' (time: 256)>
# array([131., 115., 103., ...,  nan, 109.,  75.])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  XXX
#     units:      m
#     source:     ctd
#     subset:     physical]
# creating plots [<xarray.DataArray 'MLD_potemp' (time: 256)>
# array([23., 21., nan, ..., nan, 57., 34.])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  XXX
#     units:      m
#     source:     ctd
#     subset:     physical, <xarray.DataArray 'SR_COCCOLITHOPHORIDS' (time: 256)>
# array([ 5.,  0.,  3., ..., nan,  9.,  5.])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  XXX
#     units:      number of species
#     source:     phytoplankton
#     subset:     biological, <xarray.DataArray 'SR_CYANOBACTERIA' (time: 256)>
# array([ 4.,  1.,  6., ..., nan,  2.,  1.])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  XXX
#     units:      number of species
#     source:     phytoplankton
#     subset:     biological]
# creating plots [<xarray.DataArray 'SR_DIATOMS' (time: 256)>
# array([64., 59., 53., ..., nan, 53., 38.])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  XXX
#     units:      number of species
#     source:     phytoplankton
#     subset:     biological, <xarray.DataArray 'SR_DINOFLAGELLATES' (time: 256)>
# array([18., 18., 12., ..., nan, 14., 17.])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  XXX
#     units:      number of species
#     source:     phytoplankton
#     subset:     biological, <xarray.DataArray 'SR_OTHERS' (time: 256)>
# array([ 0.,  0.,  1., ..., nan,  2.,  0.])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  XXX
#     units:      number of species
#     source:     phytoplankton
#     subset:     biological]
# creating plots [<xarray.DataArray 'species_richness' (time: 256)>
# array([91., 78., 75., ..., nan, 80., 61.])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  XXX
#     units:      number of species
#     source:     phytoplankton
#     subset:     biological, <xarray.DataArray 'counts_int_COCCOLITHOPHORIDS' (time: 256)>
# array([0.046383, 0.      , 1.00584 , ...,      nan, 0.044713, 0.004106])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  XXX
#     units:      cells/ml
#     source:     phytoplankton
#     subset:     biological, <xarray.DataArray 'counts_int_DIATOMS' (time: 256)>
# array([0.323438, 0.691707, 4.576444, ...,      nan, 0.154249, 0.133704])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  XXX
#     units:      cells/ml
#     source:     phytoplankton
#     subset:     biological]
# creating plots [<xarray.DataArray 'counts_int_DINOFLAGELLATES' (time: 256)>
# array([0.074191, 0.323511, 0.263434, ...,      nan, 0.002916, 0.011246])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  XXX
#     units:      cells/ml
#     source:     phytoplankton
#     subset:     biological, <xarray.DataArray 'counts_int_CYANOBACTERIA' (time: 256)>
# array([0.171533, 0.3975  , 0.276363, ...,      nan, 0.004689, 0.001216])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  XXX
#     units:      cells/ml
#     source:     phytoplankton
#     subset:     biological, <xarray.DataArray 'counts_int_OTHERS' (time: 256)>
# array([0.      , 0.      , 0.028984, ...,      nan, 0.012956, 0.      ])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  XXX
#     units:      cells/ml
#     source:     phytoplankton
#     subset:     biological]
# creating plots [<xarray.DataArray 'counts_int_NANOFLAGELLATES' (time: 256)>
# array([201.39917 , 327.049295, 490.93565 , ...,        nan, 254.358   ,
#        219.57    ])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  XXX
#     units:      cells/ml
#     source:     phytoplankton
#     subset:     biological, <xarray.DataArray 'Mesh200' (time: 256)>
# array([   nan,    nan,    nan, ...,    nan, 4.07  , 3.1074])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  XXX
#     units:      mg/m^3
#     source:     zooplankton
#     subset:     biological, <xarray.DataArray 'Mesh500' (time: 256)>
# array([     nan,      nan,      nan, ...,      nan, 1.26594 , 0.966536])
# Coordinates:
#   * time     (time) datetime64[ns] 1995-11-01 1995-12-01 ... 2017-01-01
# Attributes:
#     long_name:  XXX
#     units:      mg/m^3
#     source:     zooplankton
#     subset:     biological]
# PDF DONE!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/s8/8ypwvww534g_q5s51__36bmc0000gp/T/ipykernel_40390/3319419938.py in <module>
#      38
#      39     pdf.close()
# ---> 40     print("PDF DONE!")
#
# ~/opt/anaconda3/envs/xsimlab2/lib/python3.9/site-packages/matplotlib/backends/backend_pdf.py in __exit__(self, exc_type, exc_val, exc_tb)
#    2491
#    2492     def __exit__(self, exc_type, exc_val, exc_tb):
# -> 2493         self.close()
#    2494
#    2495     def close(self):
#
# ~/opt/anaconda3/envs/xsimlab2/lib/python3.9/site-packages/matplotlib/backends/backend_pdf.py in close(self)
#    2498         PDF file.
#    2499         """
# -> 2500         self._file.finalize()
#    2501         self._file.close()
#    2502         if (self.get_pagecount() == 0 and not self.keep_empty and
#
# AttributeError: 'NoneType' object has no attribute 'finalize'
