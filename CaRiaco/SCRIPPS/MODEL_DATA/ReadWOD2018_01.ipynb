# %%
from netCDF4 import Dataset, MFDataset
import numpy as np

# %%
import glob

TempNCDFfiles = glob.glob('WOA2018/Temperature/*.nc', recursive=True)

# %%
TempDATA = MFDataset(TempNCDFfiles, aggdim='time')

# %%
TempDATA.variables
# Out:
# OrderedDict([('crs', <class 'netCDF4._netCDF4.Variable'>
#               int32 crs()
#                   grid_mapping_name: latitude_longitude
#                   epsg_code: EPSG:4326
#                   longitude_of_prime_meridian: 0.0
#                   semi_major_axis: 6378137.0
#                   inverse_flattening: 298.25723
#               unlimited dimensions:
#               current shape = ()
#               filling on, default _FillValue of -2147483647 used),
#              ('lat', <class 'netCDF4._netCDF4.Variable'>
#               float32 lat(lat)
#                   standard_name: latitude
#                   long_name: latitude
#                   units: degrees_north
#                   axis: Y
#                   bounds: lat_bnds
#               unlimited dimensions:
#               current shape = (180,)
#               filling on, default _FillValue of 9.969209968386869e+36 used),
#              ('lat_bnds', <class 'netCDF4._netCDF4.Variable'>
# ...

# %%
#TempDATA.variables
#t_an('time', 'depth', 'lat', 'lon')

# %%
t_an = TempDATA.variables['t_an'][:]
depth = TempDATA.variables['depth'][:]
lon = TempDATA.variables['lon'][:]
lat = TempDATA.variables['lat'][:]
time = TempDATA.variables['time'][:]
#print(Chl)

t_units = TempDATA.variables['t_an'].units

# %%
TempDATA.close()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
plt.rcParams['figure.figsize'] = [20, 10]

# %%
lons, lats = np.meshgrid(lon, lat)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4b46be1f7f13> in <module>
# ----> 1 lons, lats = np.meshgrid(lon, lat)
#
# NameError: name 'lon' is not defined

# %%
str(lats),str(lons), str(t_an[0,0,:,:])

# %%
lats[1]

# %%
BM1 = t_an[0,10,:,:]

# %%
fig, ax = plt.subplots()
earth = Basemap(ax=ax)
earth.drawcoastlines(color='#556655', linewidth=0.5)
earth.scatter(lons, lats, BM1)
ax.set_xlabel("Global SST WOA climatology")
# Out:
# /Users/bpo/anaconda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-150d59196450> in <module>
#       2 earth = Basemap(ax=ax)
#       3 earth.drawcoastlines(color='#556655', linewidth=0.5)
# ----> 4 earth.scatter(lons, lats, BM1)
#       5 ax.set_xlabel("Global SST WOA climatology")
#
# NameError: name 'lons' is not defined
